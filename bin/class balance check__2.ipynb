# %% [markdown]
# # data split

# %%
import os
import argparse
import time
import random
import shutil

from pathlib import Path
from math import ceil

from somenlp.utils import get_time_marker
from somenlp.feature_engineering import calculate_features_parallel


import os
from os import listdir 
from collections import Counter

import os
from os import listdir 
from collections import Counter


in_path = '/home/beck/Desktop/SoMeNLP/data/PLoS_methods_bio/'
out_path = '/home/beck/Desktop/SoMeNLP/data/PLoS_methods/'

def split_data(in_path, out_path, seed_, file_ext =".data.txt", 
               ratio =[60, 20, 20], set_names = ['train', 'devel', 'test'], 
               ):
    
    in_path = in_path.rstrip('/')
    out_path = out_path.rstrip('/')

    if not os.path.isdir(in_path):
        raise(RuntimeError("Input path does not exist"))
        
    if not os.path.isdir(out_path):
        os.mkdir(out_path)
    
    if sum(ratio) != 100:
        raise(RuntimeError("Input ratio {} does not sum to 100".format(ratio)))
    if len(ratio) != len(set_names):
        raise(RuntimeError("Number of ratios and setnames has to match: {} vs {}".format(ratio, set_names)))

    #print("Loading files")
    single_files = list(Path(in_path).rglob('*{}'.format(file_ext)))
    
    all_files = []
    for entry in single_files:
        
        base_file_name = entry.name.split(file_ext)[0]
        
        base_file_entries = list(Path(in_path).rglob('{}*'.format(base_file_name)))
        
        all_files.append(base_file_entries)
    
    random.seed(seed_)
    random.shuffle(all_files)

    #print("Copying files")
    cut_sum = 0
    prev_cut_idx = 0
    for cut, name in zip(ratio, set_names):
        cut_sum += cut
        cut_idx = ceil(len(all_files) * cut_sum / 100) 
        
        out_folder_name = in_path.rsplit('/')[-1]
        new_output_location = '{}/{}_{}'.format(out_path.rstrip('/'), out_folder_name, name) 
        
        if not os.path.isdir(new_output_location):
            os.makedirs(new_output_location)
            
        for files in all_files[prev_cut_idx:cut_idx]:
            for f in files:
                source_path = str(f)
                target_path = '{}/{}'.format(new_output_location, f.name)
                shutil.copy(source_path, target_path)
        prev_cut_idx = cut_idx
    
    print("Done")
    

def purposeLabel_counter(path):
    
    import os
    from os import listdir 
    from collections import Counter
    
    
    def list_file_names(path, file_ext='.labels.txt'):
    
        file_names_list = []

        for file_name in os.listdir(path):
            if not file_name.endswith(file_ext): continue
            file_names_list.append(file_name) 

        file_names_list.sort()

        return file_names_list
    
    file_name_list = list_file_names(path)
    
    interest_list = ["Analysis", "Modelling", "Stimulation", "DataCollection", "DataPreProcss", 
                 "Simulation", "Visualization", "Programming"]
    
    all_purpose_labels = []
    
    for file_name in file_name_list[:]:
        file_path = path + file_name
        
        with open(file_path, 'r') as f:
            
            list_lines = f.readlines()
            
            #print(list_of_lebs)
            list_of_tokens = ' '.join(list_lines).split()
            
            for tok in list_of_tokens:
                if tok != 'O' and (len(tok.split('-')[1].split('_')) == 3 ):
                    if tok.split('-')[1].split('_')[2] in interest_list:
                        
                        purpose = tok.split('-')[1].split('_')[2]
                        
                        all_purpose_labels.append(purpose)
    
                        
    return  dict(Counter(all_purpose_labels))

def train_test_dev(whole_path, train_path, test_path, dev_path):
    
    _whole = purposeLabel_counter(whole_path)
    _train = purposeLabel_counter(train_path)
    _test  = purposeLabel_counter(test_path)
    _dev   = purposeLabel_counter(dev_path)
    
    
    
    _whole_sorted = dict(sorted(_whole.items()))
    _train_sorted = dict(sorted(_train.items()))
    _test_sorted  = dict(sorted(_test.items()))
    _dev_sorted   = dict(sorted(_dev.items()))
    
    return _whole_sorted, _train_sorted, _test_sorted, _dev_sorted

def __proportion_calculator_with_key(whole_dict, train_dict, test_dict, dev_dict ):
    
    train_purpose_props = []
    for (k,v), (k2,v2) in zip(whole_dict.items(), train_dict.items()):
        if k2 == k: 
            train_percentage = int(v2 / v * 100)
            train_purpose_props.append((train_percentage, k))
            
    dev_purpose_props = []
    for (k,v), (k2,v2) in zip(whole_dict.items(), dev_dict.items()):
        if k2 == k:
            
            dev_percentage = int(v2 / v * 100)
            dev_purpose_props.append((dev_percentage,k))
            
    test_purpose_props = []       
    for (k,v), (k2,v2) in zip(whole_dict.items(), test_dict.items()):
        if k2 == k:
            
            test_percentage = int(v2 / v * 100)
            test_purpose_props.append((test_percentage, k))
            
    return train_purpose_props, dev_purpose_props, test_purpose_props


def __proportion_calculator(whole_dict, train_dict, test_dict, dev_dict ):
    
    train_purpose_props = []
    for (k,v), (k2,v2) in zip(whole_dict.items(), train_dict.items()):
        if k2 == k: 
            train_percentage = int(v2 / v * 100)
            train_purpose_props.append(train_percentage)
            
    dev_purpose_props = []
    for (k,v), (k2,v2) in zip(whole_dict.items(), dev_dict.items()):
        if k2 == k:
            
            dev_percentage = int(v2 / v * 100)
            dev_purpose_props.append(dev_percentage)
            
    test_purpose_props = []       
    for (k,v), (k2,v2) in zip(whole_dict.items(), test_dict.items()):
        if k2 == k:
            
            test_percentage = int(v2 / v * 100)
            test_purpose_props.append(test_percentage)
            
    return train_purpose_props, dev_purpose_props, test_purpose_props



def _within_range(list_):
    
    bool_list = []
    for val in list_:
        if val in range(55,65):
            bool_list.append(True)
        else:
            bool_list.append(False)
            
    return all(bool_list) #, bool_list   # apply & to all and return


def _within_range_pubmed(list_):
    
    bool_list = []
    for val in list_:
        if val in range(50,70):
            bool_list.append(True)
        else:
            bool_list.append(False)
            
            
    withn_range_bool = all(bool_list) # apply & to all and return
    
    # check if all class labels are included , class label stimulation is missing in the PubMed 
    if (len(bool_list) == 7):
        all_classes_included = True
    else:
        all_classes_included = False
        
    result = all_classes_included and withn_range_bool
            
    return result   


def _within_range_dev_test(list_):
    
    bool_list = []
    for val in list_:
        if val in range(15,25):
            bool_list.append(True)
        else:
            bool_list.append(False)
            
    return all(bool_list) #, bool_list   # apply & to all and return

# %% [markdown]
# # plos_pubmed_combined

# %%
# combined plos pubmed bio   train , test , dev


in_path_comb = '/home/beck/Desktop/SoMeNLP/data/plos_pubmed_combined_bio/'
out_path_comb = '/home/beck/Desktop/SoMeNLP/data/plos_pubmed_combined/'


i = 10390

split_data(in_path_comb, out_path_comb, i)


comb_path_whole = '/home/beck/Desktop/SoMeNLP/data/plos_pubmed_combined_bio/'
comb_path_train = "/home/beck/Desktop/SoMeNLP/data/plos_pubmed_combined/plos_pubmed_combined_bio_train/" 
comb_path_test = "/home/beck/Desktop/SoMeNLP/data/plos_pubmed_combined/plos_pubmed_combined_bio_test/" 
comb_path_dev = "/home/beck/Desktop/SoMeNLP/data/plos_pubmed_combined/plos_pubmed_combined_bio_devel/"
    
    
#calculate the distribution of class_labels for cmbined set
comb_whole_dict, comb_train_dict, comb_test_dict, comb_dev_dict = train_test_dev(comb_path_whole, 
                                                                                 comb_path_train, 
                                                                                 comb_path_test, 
                                                                                 comb_path_dev)


# calculate the proportion for each class label (8 - purposes)
comb_train_props, comb_dev_props, comb_test_props = __proportion_calculator(comb_whole_dict, 
                                                                            comb_train_dict, 
                                                                            comb_test_dict, 
                                                                            comb_dev_dict)


comb_train_result_ = _within_range_pubmed(comb_train_props)
comb_test_result_  = _within_range_dev_test(comb_test_props)
comb_dev_result_   = _within_range_dev_test(comb_dev_props)

print(f'plos+pubmed train {comb_train_props, _within_range(comb_train_props)}')
print(f'plos+pubmed test  {comb_test_props, _within_range_dev_test(comb_test_props)}')
print(f'plos+pubmed dev   {comb_dev_props, _within_range_dev_test(comb_dev_props)}')
print()

print(f"plos+pubmed train within +/- 60% ? {_within_range(comb_train_props)}")
print(f"plos+pubmed test  within +/- 15% ? {_within_range_dev_test(comb_test_props)}")
print(f"plos+pubmed dev   within +/- 15% ? {_within_range_dev_test(comb_dev_props)}")
print()

# train percentage 60%
    
for (k,v), (k2,v2) in zip(comb_whole_dict.items(),  comb_train_dict.items()):
    if k2 == k:
        print(f"{k2 :{18}}  {v2}/{v} train {v2/v*100: .2f}% ")

# test percentage 20% 
print()

for (k,v), (k2,v2) in zip(comb_whole_dict.items(),  comb_test_dict.items()):
    if k2 == k:
        print(f"{k2 :{18}}  {v2}/{v} test {v2/v*100: .2f}% ")
        
# dev percentage 20% 
print()

for (k,v), (k2,v2) in zip(comb_whole_dict.items(),  comb_dev_dict.items()):
    if k2 == k:
        print(f"{k2 :{18}}  {v2}/{v} dev {v2/v*100: .2f}% ")
# Out:
# Done
# plos+pubmed train ([64, 56, 65, 69, 60, 85, 49, 59], False)
# plos+pubmed test  ([18, 22, 22, 20, 28, 7, 19, 23], False)
# plos+pubmed dev   ([16, 21, 12, 10, 11, 7, 30, 17], False)
#
# plos+pubmed train within +/- 60% ? False
# plos+pubmed test  within +/- 15% ? False
# plos+pubmed dev   within +/- 15% ? False
#
# Analysis            932/1436 train  64.90%
# DataCollection      138/246 train  56.10%
# DataPreProcss       220/335 train  65.67%
# Modelling           158/227 train  69.60%
# Programming         48/80 train  60.00%
# Simulation          24/28 train  85.71%
# Stimulation         35/71 train  49.30%
# Visualization       70/117 train  59.83%
#
# Analysis            269/1436 test  18.73%
# DataCollection      56/246 test  22.76%
# DataPreProcss       74/335 test  22.09%
# Modelling           46/227 test  20.26%
# Programming         23/80 test  28.75%
# Simulation          2/28 test  7.14%
# Stimulation         14/71 test  19.72%
# Visualization       27/117 test  23.08%
#
# Analysis            235/1436 dev  16.36%
# DataCollection      52/246 dev  21.14%
# DataPreProcss       41/335 dev  12.24%
# Modelling           23/227 dev  10.13%
# Programming         9/80 dev  11.25%
# Simulation          2/28 dev  7.14%
# Stimulation         22/71 dev  30.99%
# Visualization       20/117 dev  17.09%

# %%
# combined plos pubmed bio   train , test , dev


in_path_comb = '/home/beck/Desktop/SoMeNLP/data/plos_pubmed_combined_bio/'
out_path_comb = '/home/beck/Desktop/SoMeNLP/data/plos_pubmed_combined/'

stable_split_seeds = []

i = 0

split_data(in_path_comb, out_path_comb, i)


comb_path_whole = '/home/beck/Desktop/SoMeNLP/data/plos_pubmed_combined_bio/'
comb_path_train = "/home/beck/Desktop/SoMeNLP/data/plos_pubmed_combined/plos_pubmed_combined_bio_train/" 
comb_path_test = "/home/beck/Desktop/SoMeNLP/data/plos_pubmed_combined/plos_pubmed_combined_bio_test/" 
comb_path_dev = "/home/beck/Desktop/SoMeNLP/data/plos_pubmed_combined/plos_pubmed_combined_bio_devel/"
    
    
#calculate the distribution of class_labels for cmbined set
comb_whole_dict, comb_train_dict, comb_test_dict, comb_dev_dict = train_test_dev(comb_path_whole, 
                                                                                 comb_path_train, 
                                                                                 comb_path_test, 
                                                                                 comb_path_dev)


# calculate the proportion for each class label (8 - purposes)
comb_train_props, comb_dev_props, comb_test_props = __proportion_calculator(comb_whole_dict, 
                                                                            comb_train_dict, 
                                                                            comb_test_dict, 
                                                                            comb_dev_dict)


comb_train_result_ = _within_range_pubmed(comb_train_props)
comb_test_result_  = _within_range_dev_test(comb_test_props)
comb_dev_result_   = _within_range_dev_test(comb_dev_props)

bool_ = (comb_train_result_) and (comb_test_result_) and (comb_dev_result_)



while not(bool_):
    
    print(f'splitting ... with seed: {i}')
    
    split_data(in_path_comb, out_path_comb, i)
    
    i += 1
    
    
    
    #calculate the distribution of class_labels for cmbined set
    comb_whole_dict, comb_train_dict, comb_test_dict, comb_dev_dict = train_test_dev(comb_path_whole, 
                                                                                 comb_path_train, 
                                                                                 comb_path_test, 
                                                                                 comb_path_dev)


    # calculate the proportion for each class label (8 - purposes)
    comb_train_props, comb_dev_props, comb_test_props = __proportion_calculator(comb_whole_dict, 
                                                                            comb_train_dict, 
                                                                            comb_test_dict, 
                                                                            comb_dev_dict)
    #print('is the split fair ?')
    comb_train_result_ = _within_range(comb_train_props)
    comb_test_result  = _within_range_dev_test(comb_test_props)
    comb_dev_result   = _within_range_dev_test(comb_dev_props)
    print()
    
    bool_ = (comb_train_result_) and (comb_test_result_) and (comb_dev_result_)
    

    
    
    if bool_:
        print()
        print('plos_pubmed split is balanced. stopped splitting')
        print(f'result:  {comb_train_result_, comb_test_result, comb_dev_result}') 
        stable_split_seeds.append(i)
        break
        
    else:
        
        shutil.rmtree(comb_path_train, ignore_errors=False, onerror=None)
        shutil.rmtree(comb_path_test, ignore_errors=False, onerror=None)
        shutil.rmtree(comb_path_dev, ignore_errors=False, onerror=None)
        
        print(f'result:  {comb_train_result_, comb_test_result, comb_dev_result}')   
        print(f'plos_pubmed split is not yet balanced {comb_train_props, comb_dev_props, comb_test_props}.  splitting further ...')
        print()
# Out:
# Done
# splitting ... with seed: 0
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([62, 48, 59, 68, 46, 53, 33, 45], [17, 13, 15, 11, 41, 25, 45, 17], [20, 38, 24, 20, 12, 21, 21, 37]).  splitting further ...
#
# splitting ... with seed: 1
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([60, 56, 65, 73, 72, 75, 50, 56], [21, 21, 20, 10, 13, 7, 22, 32], [17, 21, 14, 15, 13, 17, 26, 11]).  splitting further ...
#
# splitting ... with seed: 2
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([61, 61, 58, 66, 60, 46, 59, 55], [19, 21, 23, 20, 26, 32, 16, 25], [19, 16, 18, 13, 13, 21, 23, 18]).  splitting further ...
#
# splitting ... with seed: 3
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([60, 60, 62, 60, 46, 71, 38, 68], [20, 13, 15, 20, 16, 21, 18, 5], [19, 26, 21, 18, 37, 7, 43, 25]).  splitting further ...
#
# splitting ... with seed: 4
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([64, 70, 65, 62, 51, 78, 52, 59], [15, 9, 15, 12, 22, 3, 30, 12], [19, 19, 19, 24, 26, 17, 16, 27]).  splitting further ...
#
# splitting ... with seed: 5
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([61, 57, 59, 60, 56, 42, 45, 70], [20, 27, 16, 17, 15, 28, 21, 17], [18, 15, 23, 22, 28, 28, 33, 11]).  splitting further ...
#
# splitting ... with seed: 6
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([58, 51, 56, 53, 36, 53, 70, 62], [22, 28, 21, 24, 32, 7, 16, 21], [18, 20, 22, 22, 31, 39, 12, 16]).  splitting further ...
#
# splitting ... with seed: 7
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([62, 65, 55, 63, 50, 57, 49, 59], [23, 18, 25, 18, 22, 10, 32, 22], [13, 15, 18, 17, 27, 32, 18, 17]).  splitting further ...
#
# splitting ... with seed: 8
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([66, 69, 72, 65, 53, 60, 40, 65], [15, 14, 17, 14, 32, 25, 21, 16], [17, 16, 9, 20, 13, 14, 38, 17]).  splitting further ...
#
# splitting ... with seed: 9
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([61, 65, 62, 63, 58, 85, 54, 57], [17, 17, 22, 15, 3, 10, 39, 29], [20, 16, 14, 20, 37, 3, 5, 13]).  splitting further ...
#
# splitting ... with seed: 10
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([59, 71, 62, 60, 36, 46, 70, 67], [21, 15, 11, 13, 40, 32, 12, 22], [19, 12, 25, 25, 23, 21, 16, 10]).  splitting further ...
#
# splitting ... with seed: 11
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([56, 66, 56, 66, 48, 53, 70, 55], [20, 16, 22, 10, 15, 28, 9, 25], [22, 17, 21, 22, 36, 17, 19, 18]).  splitting further ...
#
# splitting ... with seed: 12
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([62, 61, 68, 69, 63, 35, 59, 72], [16, 15, 14, 9, 13, 35, 14, 15], [20, 22, 17, 21, 22, 28, 26, 11]).  splitting further ...
#
# splitting ... with seed: 13
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([61, 60, 62, 73, 51, 42, 47, 66], [17, 19, 13, 14, 27, 21, 8, 18], [20, 19, 24, 12, 21, 35, 43, 14]).  splitting further ...
#
# splitting ... with seed: 14
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([63, 60, 61, 59, 33, 53, 60, 57], [21, 17, 19, 17, 35, 21, 22, 20], [15, 22, 18, 22, 31, 25, 16, 22]).  splitting further ...
#
# splitting ... with seed: 15
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([61, 47, 67, 49, 37, 53, 61, 58], [20, 27, 16, 22, 33, 28, 28, 32], [17, 24, 15, 27, 28, 17, 9, 9]).  splitting further ...
#
# splitting ... with seed: 16
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([58, 61, 56, 55, 91, 60, 64, 71], [19, 17, 28, 17, 3, 10, 7, 16], [21, 20, 14, 26, 5, 28, 28, 11]).  splitting further ...
#
# splitting ... with seed: 17
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([61, 58, 69, 72, 77, 75, 60, 61], [20, 23, 15, 16, 11, 3, 12, 19], [18, 17, 14, 10, 11, 21, 26, 18]).  splitting further ...
#
# splitting ... with seed: 18
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([58, 60, 62, 61, 53, 57, 66, 63], [20, 15, 13, 17, 31, 28, 28, 23], [21, 23, 24, 21, 15, 14, 5, 13]).  splitting further ...
#
# splitting ... with seed: 19
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([60, 63, 71, 62, 33, 60, 49, 58], [19, 23, 14, 24, 57, 10, 16, 21], [20, 12, 13, 13, 8, 28, 33, 19]).  splitting further ...
#
# splitting ... with seed: 20
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([66, 59, 66, 70, 67, 82, 46, 71], [15, 19, 15, 17, 25, 14, 19, 13], [18, 21, 17, 12, 7, 3, 33, 14]).  splitting further ...
#
# splitting ... with seed: 21
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([63, 65, 69, 59, 51, 57, 78, 68], [17, 20, 8, 19, 31, 25, 15, 21], [18, 14, 21, 20, 17, 17, 5, 10]).  splitting further ...
#
# splitting ... with seed: 22
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([64, 64, 58, 59, 60, 67, 64, 55], [17, 17, 21, 22, 17, 7, 25, 21], [18, 17, 19, 18, 22, 25, 9, 23]).  splitting further ...
#
# splitting ... with seed: 23
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([62, 53, 51, 58, 61, 60, 61, 60], [17, 14, 28, 27, 13, 10, 14, 14], [20, 31, 20, 13, 25, 28, 23, 24]).  splitting further ...
#
# splitting ... with seed: 24
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([65, 65, 66, 56, 66, 50, 69, 61], [20, 18, 17, 25, 8, 42, 18, 23], [14, 15, 16, 17, 25, 7, 12, 14]).  splitting further ...
#
# splitting ... with seed: 25
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([61, 67, 62, 55, 48, 67, 60, 64], [14, 7, 6, 15, 30, 25, 25, 5], [24, 24, 31, 28, 21, 7, 14, 29]).  splitting further ...
#
# splitting ... with seed: 26
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([61, 54, 63, 56, 76, 64, 42, 66], [18, 30, 9, 25, 6, 28, 38, 12], [20, 15, 26, 17, 17, 7, 19, 20]).  splitting further ...
#
# splitting ... with seed: 27
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([65, 54, 66, 60, 66, 67, 60, 58], [16, 22, 14, 21, 21, 7, 26, 23], [17, 22, 18, 17, 12, 25, 12, 17]).  splitting further ...
#
# splitting ... with seed: 28
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([62, 66, 71, 54, 46, 50, 38, 49], [19, 10, 19, 30, 16, 25, 19, 31], [18, 22, 9, 14, 37, 25, 42, 18]).  splitting further ...
#
# splitting ... with seed: 29
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([59, 57, 55, 48, 53, 60, 45, 66], [21, 18, 25, 25, 11, 32, 38, 17], [18, 23, 19, 26, 35, 7, 16, 16]).  splitting further ...
#
# splitting ... with seed: 30
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([61, 70, 62, 64, 51, 32, 78, 58], [15, 15, 11, 17, 37, 25, 2, 21], [22, 14, 25, 18, 11, 42, 18, 19]).  splitting further ...
#
# splitting ... with seed: 31
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([63, 63, 64, 59, 56, 64, 64, 74], [18, 17, 18, 19, 20, 21, 21, 11], [18, 19, 17, 21, 23, 14, 14, 14]).  splitting further ...
#
# splitting ... with seed: 32
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([60, 71, 64, 51, 67, 71, 38, 62], [18, 18, 19, 22, 16, 25, 30, 18], [21, 10, 16, 25, 16, 3, 30, 18]).  splitting further ...
#
# splitting ... with seed: 33
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([58, 60, 65, 60, 72, 53, 59, 76], [22, 19, 20, 26, 10, 28, 14, 11], [19, 19, 13, 12, 17, 17, 26, 11]).  splitting further ...
#
# splitting ... with seed: 34
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([67, 58, 68, 62, 56, 50, 42, 75], [15, 19, 9, 17, 21, 35, 23, 11], [17, 21, 22, 19, 22, 14, 33, 13]).  splitting further ...
#
# splitting ... with seed: 35
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([56, 51, 51, 59, 51, 46, 63, 56], [20, 20, 26, 25, 10, 32, 19, 20], [22, 28, 21, 14, 38, 21, 16, 23]).  splitting further ...
#
# splitting ... with seed: 36
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([52, 59, 51, 55, 77, 67, 74, 54], [24, 21, 26, 14, 3, 10, 4, 17], [23, 18, 22, 29, 18, 21, 21, 27]).  splitting further ...
#
# splitting ... with seed: 37
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([66, 68, 72, 70, 72, 53, 66, 59], [12, 12, 10, 11, 17, 17, 23, 18], [20, 19, 17, 18, 10, 28, 9, 21]).  splitting further ...
#
# splitting ... with seed: 38
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([59, 62, 60, 66, 82, 64, 42, 64], [21, 24, 16, 16, 6, 28, 43, 25], [18, 13, 22, 17, 11, 7, 14, 9]).  splitting further ...
#
# splitting ... with seed: 39
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([54, 48, 52, 47, 25, 82, 38, 47], [15, 19, 11, 19, 41, 3, 46, 22], [30, 31, 36, 33, 33, 14, 15, 29]).  splitting further ...
#
# splitting ... with seed: 40
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([60, 57, 56, 59, 71, 35, 52, 60], [19, 25, 22, 26, 23, 46, 26, 17], [20, 17, 20, 13, 5, 17, 21, 21]).  splitting further ...
#
# splitting ... with seed: 41
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([64, 62, 62, 72, 56, 39, 64, 63], [19, 17, 17, 8, 26, 21, 15, 9], [16, 19, 19, 18, 17, 39, 19, 27]).  splitting further ...
#
# splitting ... with seed: 42
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([61, 60, 57, 59, 61, 50, 63, 47], [18, 21, 19, 17, 27, 50, 14, 39], [20, 17, 22, 22, 11]).  splitting further ...
#
# splitting ... with seed: 43
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([54, 63, 51, 45, 53, 75, 46, 42], [23, 15, 25, 30, 7, 7, 11, 32], [22, 21, 22, 23, 38, 17, 42, 24]).  splitting further ...
#
# splitting ... with seed: 44
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([53, 58, 51, 51, 76, 35, 53, 57], [22, 20, 23, 34, 15, 32, 26, 26], [23, 21, 24, 13, 8, 32, 19, 16]).  splitting further ...
#
# splitting ... with seed: 45
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([58, 55, 60, 60, 36, 82, 71, 55], [21, 24, 20, 16, 30, 14, 21, 23], [20, 20, 18, 23, 33, 3, 7, 21]).  splitting further ...
#
# splitting ... with seed: 46
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([55, 59, 56, 66, 38, 39, 63, 67], [28, 23, 35, 23, 33, 39, 16, 22], [15, 16, 8, 10, 27, 21, 19, 10]).  splitting further ...
#
# splitting ... with seed: 47
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([63, 60, 58, 61, 57, 50, 60, 58], [18, 24, 15, 17, 33, 21, 15, 27], [18, 14, 25, 21, 8, 28, 23, 14]).  splitting further ...
#
# splitting ... with seed: 48
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([54, 67, 62, 43, 62, 67, 71, 50], [17, 15, 9, 21, 25, 7, 16, 27], [28, 16, 28, 34, 12, 25, 11, 22]).  splitting further ...
#
# splitting ... with seed: 49
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([63, 53, 62, 54, 76, 53, 67, 54], [17, 21, 16, 26, 18, 17, 18, 28], [19, 24, 21, 19, 5, 28, 14, 17]).  splitting further ...
#
# splitting ... with seed: 50
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([58, 50, 66, 57, 55, 42, 47, 54], [20, 23, 22, 27, 2, 35, 21, 20], [20, 26, 10, 14, 42, 21, 30, 24]).  splitting further ...
#
# splitting ... with seed: 51
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([60, 57, 71, 59, 50, 60, 53, 67], [19, 15, 16, 21, 10, 25, 4, 15], [19, 27, 11, 18, 40, 14, 42, 17]).  splitting further ...
#
# splitting ... with seed: 52
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([61, 57, 63, 63, 55, 39, 56, 52], [18, 16, 14, 13, 13, 21, 29, 32], [20, 26, 21, 22, 31, 39, 14, 15]).  splitting further ...
#
# splitting ... with seed: 53
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([65, 66, 66, 65, 52, 71, 54, 64], [17, 12, 11, 18, 22, 3, 21, 16], [17, 20, 21, 15, 25, 25, 23, 18]).  splitting further ...
#
# splitting ... with seed: 54
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([65, 68, 68, 59, 65, 85, 49, 66], [16, 12, 11, 16, 32, 3, 38, 23], [18, 19, 19, 23, 2, 10, 12, 10]).  splitting further ...
#
# splitting ... with seed: 55
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([59, 56, 57, 67, 71, 82, 57, 64], [23, 26, 20, 18, 8, 3, 21, 24], [17, 16, 21, 14, 20, 14, 21, 10]).  splitting further ...
#
# splitting ... with seed: 56
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([61, 60, 64, 62, 67, 39, 69, 66], [18, 21, 19, 18, 28, 25, 11, 7], [19, 18, 15, 18, 3, 35, 19, 25]).  splitting further ...
#
# splitting ... with seed: 57
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([57, 60, 52, 52, 46, 46, 67, 66], [24, 19, 26, 31, 41, 14, 25, 17], [17, 19, 20, 16, 12, 39, 7, 15]).  splitting further ...
#
# splitting ... with seed: 58
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([64, 54, 64, 57, 42, 82, 45, 70], [20, 32, 20, 21, 37, 10, 30, 20], [15, 13, 14, 20, 20, 7, 23, 9]).  splitting further ...
#
# splitting ... with seed: 59
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([58, 59, 62, 55, 65, 42, 73, 48], [20, 21, 22, 14, 25, 25, 16, 23], [21, 18, 15, 30, 10, 32, 9, 28]).  splitting further ...
#
# splitting ... with seed: 60
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([58, 63, 65, 58, 83, 78, 61, 67], [21, 17, 20, 23, 11, 7, 9, 11], [20, 19, 14, 18, 5, 14, 28, 21]).  splitting further ...
#
# splitting ... with seed: 61
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([53, 58, 61, 64, 77, 50, 66, 49], [23, 20, 21, 23, 5, 3, 12, 23], [22, 20, 17, 11, 17, 46, 21, 27]).  splitting further ...
#
# splitting ... with seed: 62
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([61, 51, 67, 51, 27, 57, 42, 62], [19, 28, 22, 23, 36, 10, 14, 16], [19, 19, 10, 25, 36, 32, 43, 21]).  splitting further ...
#
# splitting ... with seed: 63
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([63, 57, 65, 66, 75, 53, 47, 61], [19, 15, 15, 18, 12, 25, 35, 20], [17, 26, 18, 14, 12, 21, 16, 17]).  splitting further ...
#
# splitting ... with seed: 64
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([67, 60, 64, 62, 70, 53, 73, 62], [16, 20, 19, 18, 10, 7, 12, 11], [15, 18, 16, 18, 20, 39, 14, 26]).  splitting further ...
#
# splitting ... with seed: 65
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([62, 60, 68, 67, 83, 35, 70, 60], [19, 22, 14, 10, 6, 50, 7, 12], [17, 17, 17, 22, 10, 14, 22, 26]).  splitting further ...
#
# splitting ... with seed: 66
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([62, 59, 65, 55, 41, 46, 59, 73], [16, 19, 13, 17, 25, 35, 15, 14], [21, 21, 21, 27, 33, 17, 25, 11]).  splitting further ...
#
# splitting ... with seed: 67
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([60, 60, 67, 59, 76, 64, 77, 69], [21, 18, 21, 16, 2, 25, 12, 20], [18, 21, 11, 23, 21, 10, 9, 10]).  splitting further ...
#
# splitting ... with seed: 68
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([62, 57, 66, 65, 58, 53, 57, 67], [17, 23, 16, 14, 31, 17, 15, 18], [19, 19, 17, 19, 10, 28, 26, 13]).  splitting further ...
#
# splitting ... with seed: 69
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([63, 61, 67, 66, 38, 67, 47, 70], [19, 15, 19, 19, 31, 21, 26, 18], [16, 23, 12, 14, 30, 10, 25, 10]).  splitting further ...
#
# splitting ... with seed: 70
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([58, 65, 57, 70, 50, 67, 39, 54], [18, 16, 22, 15, 30, 25, 32, 25], [23, 18, 20, 13, 20, 7, 28, 19]).  splitting further ...
#
# splitting ... with seed: 71
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([57, 47, 46, 49, 77, 46, 52, 47], [19, 22, 24, 22, 8, 39, 21, 20], [22, 29, 28, 27, 13, 14, 26, 32]).  splitting further ...
#
# splitting ... with seed: 72
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([60, 59, 59, 52, 68, 42, 45, 61], [16, 19, 16, 24, 11, 42, 9, 19], [22, 21, 24, 22, 20, 14, 45, 18]).  splitting further ...
#
# splitting ... with seed: 73
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([58, 56, 62, 50, 72, 39, 67, 54], [21, 22, 24, 34, 15, 10, 19, 15], [19, 21, 13, 14, 12, 50, 12, 29]).  splitting further ...
#
# splitting ... with seed: 74
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([58, 52, 65, 59, 53, 46, 60, 61], [19, 21, 14, 19, 11, 25, 15, 23], [22, 26, 20, 21, 35, 28, 23, 15]).  splitting further ...
#
# splitting ... with seed: 75
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([64, 59, 60, 68, 46, 57, 60, 67], [20, 21, 21, 17, 31, 35, 21, 22], [15, 18, 17, 14, 22, 7, 18, 10]).  splitting further ...
#
# splitting ... with seed: 76
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([57, 55, 52, 54, 78, 50, 69, 47], [21, 26, 31, 23, 8, 14, 26, 29], [21, 18, 15, 22, 12, 35, 4, 23]).  splitting further ...
#
# splitting ... with seed: 77
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([59, 56, 66, 65, 66, 67, 54, 52], [20, 24, 16, 12, 21, 21, 39, 27], [19, 18, 17, 22, 12, 10, 5, 20]).  splitting further ...
#
# splitting ... with seed: 78
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([63, 60, 58, 66, 48, 50, 56, 59], [17, 19, 18, 18, 28, 17, 16, 19], [19, 19, 22, 14, 22, 32, 26, 20]).  splitting further ...
#
# splitting ... with seed: 79
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([60, 56, 61, 61, 75, 71, 61, 62], [19, 20, 15, 22, 12, 25, 23, 29], [19, 23, 23, 15, 12, 3, 14, 8]).  splitting further ...
#
# splitting ... with seed: 80
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([65, 58, 76, 67, 72, 67, 59, 67], [19, 26, 16, 22, 20, 17, 29, 19], [15, 15, 6, 10, 7, 14, 11, 12]).  splitting further ...
#
# splitting ... with seed: 81
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([67, 56, 70, 60, 45, 78, 42, 73], [16, 23, 20, 17, 31, 3, 25, 11], [16, 20, 9, 21, 23, 17, 32, 15]).  splitting further ...
#
# splitting ... with seed: 82
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([56, 50, 54, 58, 63, 46, 69, 36], [21, 25, 30, 26, 11, 35, 15, 32], [22, 24, 15, 14, 25, 17, 15, 30]).  splitting further ...
#
# splitting ... with seed: 83
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([62, 61, 67, 71, 66, 32, 63, 68], [17, 26, 13, 13, 7, 57, 26, 11], [19, 11, 19, 14, 26, 10, 9, 20]).  splitting further ...
#
# splitting ... with seed: 84
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([56, 58, 51, 50, 51, 71, 73, 71], [26, 26, 36, 25, 26, 7, 15, 12], [16, 14, 12, 24, 22, 21, 11, 15]).  splitting further ...
#
# splitting ... with seed: 85
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([60, 61, 51, 60, 53, 96, 60, 64], [15, 21, 13, 11, 20, 3, 12, 14], [24, 17, 34, 27, 26]).  splitting further ...
#
# splitting ... with seed: 86
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([61, 64, 57, 65, 33, 53, 71, 60], [18, 16, 20, 21, 15, 14, 16, 23], [20, 18, 21, 13, 51, 32, 11, 16]).  splitting further ...
#
# splitting ... with seed: 87
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([60, 57, 63, 58, 58, 42, 43, 68], [22, 15, 17, 17, 7, 32, 23, 11], [16, 27, 19, 23, 33, 25, 32, 20]).  splitting further ...
#
# splitting ... with seed: 88
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([57, 55, 54, 63, 65, 71, 71, 61], [21, 20, 18, 12, 21, 10, 9, 22], [20, 24, 26, 23, 13, 17, 18, 16]).  splitting further ...
#
# splitting ... with seed: 89
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([61, 71, 67, 67, 66, 53, 80, 58], [16, 13, 18, 15, 26, 14, 4, 17], [22, 15, 14, 17, 7, 32, 15, 23]).  splitting further ...
#
# splitting ... with seed: 90
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([60, 53, 60, 66, 77, 64, 67, 64], [18, 21, 21, 12, 10, 17, 7, 13], [21, 24, 17, 20, 12, 17, 25, 22]).  splitting further ...
#
# splitting ... with seed: 91
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([55, 53, 36, 48, 53, 50, 61, 52], [20, 24, 24, 21, 27, 35, 28, 26], [23, 21, 38, 30, 18, 14, 9, 20]).  splitting further ...
#
# splitting ... with seed: 92
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([58, 67, 59, 59, 71, 39, 78, 66], [24, 15, 23, 23, 22, 10, 14, 17], [16, 17, 17, 17, 6, 50, 7, 16]).  splitting further ...
#
# splitting ... with seed: 93
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([57, 61, 62, 68, 80, 50, 45, 53], [21, 13, 19, 16, 15, 21, 33, 21], [21, 24, 17, 14, 5, 28, 21, 24]).  splitting further ...
#
# splitting ... with seed: 94
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([59, 65, 67, 66, 51, 42, 67, 54], [20, 18, 19, 11, 32, 39, 18, 18], [19, 15, 12, 22, 16, 17, 14, 26]).  splitting further ...
#
# splitting ... with seed: 95
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([64, 67, 70, 57, 56, 35, 69, 57], [19, 22, 11, 21, 21, 35, 21, 17], [16, 9, 17, 20, 22, 28, 9, 25]).  splitting further ...
#
# splitting ... with seed: 96
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([60, 46, 53, 55, 76, 67, 49, 54], [20, 28, 20, 26, 5, 14, 22, 20], [19, 25, 26, 18, 18, 17, 28, 24]).  splitting further ...
#
# splitting ... with seed: 97
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([59, 63, 70, 73, 61, 71, 46, 66], [17, 13, 14, 12, 30, 28, 26, 14], [22, 22, 15, 14, 8]).  splitting further ...
#
# splitting ... with seed: 98
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([63, 69, 77, 57, 67, 50, 60, 52], [21, 15, 11, 18, 13, 17, 25, 23], [15, 15, 11, 24, 18, 32, 14, 23]).  splitting further ...
#
# splitting ... with seed: 99
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([59, 56, 55, 57, 62, 67, 66, 55], [19, 19, 19, 15, 8, 21, 16, 31], [21, 23, 24, 27, 28, 10, 16, 12]).  splitting further ...
#
# splitting ... with seed: 100
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([56, 47, 62, 53, 47, 57, 71, 37], [23, 27, 19, 32, 26, 14, 14, 23], [19, 25, 17, 14, 26, 28, 14, 39]).  splitting further ...
#
# splitting ... with seed: 101
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([57, 63, 66, 54, 57, 64, 84, 52], [24, 17, 20, 24, 13, 10, 4, 30], [18, 19, 13, 21, 28, 25, 11, 17]).  splitting further ...
#
# splitting ... with seed: 102
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([59, 50, 55, 55, 81, 53, 35, 49], [18, 21, 19, 27, 11, 21, 38, 25], [22, 28, 25, 17, 7, 25, 26, 24]).  splitting further ...
#
# splitting ... with seed: 103
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([58, 58, 45, 37, 51, 46, 47, 47], [20, 21, 30, 32, 31, 32, 18, 29], [20, 20, 24, 29, 17, 21, 33, 23]).  splitting further ...
#
# splitting ... with seed: 104
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([62, 63, 60, 59, 60, 67, 45, 72], [19, 18, 20, 22, 31, 14, 25, 17], [17, 18, 18, 18, 8, 17, 29, 10]).  splitting further ...
#
# splitting ... with seed: 105
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([67, 53, 72, 61, 30, 67, 63, 67], [14, 24, 15, 23, 43, 21, 30, 11], [17, 21, 11, 14, 26, 10, 5, 20]).  splitting further ...
#
# splitting ... with seed: 106
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([64, 58, 57, 58, 76, 46, 71, 53], [15, 19, 14, 20, 6, 35, 16, 26], [19, 21, 28, 21, 17, 17, 11, 19]).  splitting further ...
#
# splitting ... with seed: 107
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([54, 52, 41, 55, 80, 46, 64, 62], [27, 24, 29, 15, 10, 25, 16, 22], [17, 23, 29, 29, 10, 28, 18, 15]).  splitting further ...
#
# splitting ... with seed: 108
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([60, 61, 54, 63, 50, 67, 40, 53], [23, 23, 36, 17, 18, 21, 26, 17], [16, 15, 9, 18, 31, 10, 32, 28]).  splitting further ...
#
# splitting ... with seed: 109
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([60, 62, 59, 56, 72, 67, 53, 60], [19, 20, 13, 29, 5, 7, 33, 13], [20, 17, 27, 14, 22, 25, 12, 25]).  splitting further ...
#
# splitting ... with seed: 110
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([59, 64, 60, 62, 77, 53, 64, 58], [16, 13, 14, 15, 10, 14, 25, 23], [23, 21, 25, 21, 12, 32, 9, 17]).  splitting further ...
#
# splitting ... with seed: 111
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([53, 56, 48, 45, 58, 67, 53, 52], [26, 23, 32, 19, 20, 28, 26, 19], [20, 19, 18, 34, 21, 3, 19, 27]).  splitting further ...
#
# splitting ... with seed: 112
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([59, 64, 53, 66, 77, 39, 57, 63], [18, 20, 19, 14, 5, 32, 12, 10], [21, 15, 27, 19, 17, 28, 29, 26]).  splitting further ...
#
# splitting ... with seed: 113
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([59, 63, 61, 63, 55, 35, 74, 55], [22, 19, 20, 20, 25, 42, 12, 18], [18, 16, 17, 15, 20, 21, 12, 25]).  splitting further ...
#
# splitting ... with seed: 114
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([56, 62, 57, 59, 40, 42, 61, 56], [23, 17, 27, 18, 28, 10, 23, 14], [19, 20, 15, 22, 31, 46, 14, 29]).  splitting further ...
#
# splitting ... with seed: 115
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([65, 69, 58, 56, 75, 71, 56, 56], [17, 15, 22, 27, 20, 7, 23, 17], [17, 14, 18, 15, 5, 21, 19, 25]).  splitting further ...
#
# splitting ... with seed: 116
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([55, 58, 56, 57, 67, 50, 77, 66], [21, 21, 22, 20, 13, 14, 18, 17], [22, 19, 20, 22, 18, 35, 4, 16]).  splitting further ...
#
# splitting ... with seed: 117
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([61, 70, 67, 57, 68, 39, 57, 64], [17, 18, 15, 16, 7, 39, 18, 18], [21, 10, 16, 25, 23, 21, 23, 17]).  splitting further ...
#
# splitting ... with seed: 118
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([56, 56, 59, 53, 58, 57, 69, 51], [19, 15, 22, 18, 8, 7, 15, 11], [24, 28, 18, 27, 32, 35, 15, 37]).  splitting further ...
#
# splitting ... with seed: 119
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([60, 58, 51, 56, 50, 67, 45, 66], [21, 19, 30, 27, 23, 7, 25, 17], [18, 21, 18, 15, 26, 25, 29, 16]).  splitting further ...
#
# splitting ... with seed: 120
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([60, 67, 61, 53, 57, 64, 71, 77], [21, 17, 27, 23, 36, 35, 16, 13], [17, 15, 10, 22, 6]).  splitting further ...
#
# splitting ... with seed: 121
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([55, 52, 56, 55, 51, 32, 64, 70], [22, 28, 19, 23, 13, 35, 12, 8], [22, 19, 24, 21, 35, 32, 22, 21]).  splitting further ...
#
# splitting ... with seed: 122
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([64, 53, 69, 61, 55, 60, 69, 62], [19, 17, 14, 18, 12, 10, 22, 21], [16, 28, 15, 19, 32, 28, 8, 16]).  splitting further ...
#
# splitting ... with seed: 123
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([54, 56, 47, 49, 61, 50, 74, 56], [18, 18, 17, 16, 13, 7, 11, 12], [27, 24, 34, 33, 25, 42, 14, 30]).  splitting further ...
#
# splitting ... with seed: 124
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([63, 53, 59, 51, 66, 50, 50, 55], [19, 22, 21, 18, 7, 28, 28, 27], [16, 23, 18, 29, 26, 21, 21, 17]).  splitting further ...
#
# splitting ... with seed: 125
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([62, 55, 64, 53, 58, 67, 36, 63], [18, 13, 12, 25, 17, 17, 28, 14], [19, 31, 23, 21, 23, 14, 35, 22]).  splitting further ...
#
# splitting ... with seed: 126
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([60, 68, 58, 55, 51, 46, 67, 63], [25, 13, 26, 28, 18, 39, 15, 20], [14, 17, 14, 15, 30, 14, 16, 16]).  splitting further ...
#
# splitting ... with seed: 127
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([55, 66, 57, 51, 62, 46, 59, 56], [22, 14, 18, 19, 7, 28, 22, 20], [22, 19, 23, 28, 30, 25, 18, 23]).  splitting further ...
#
# splitting ... with seed: 128
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([59, 64, 68, 67, 71, 67, 66, 61], [20, 19, 17, 11, 21, 21, 22, 17], [19, 16, 14, 21, 7, 10, 11, 20]).  splitting further ...
#
# splitting ... with seed: 129
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([58, 59, 62, 59, 32, 85, 66, 77], [20, 20, 20, 25, 52, 10, 28, 15], [21, 19, 17, 14, 15, 3, 5, 6]).  splitting further ...
#
# splitting ... with seed: 130
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([55, 57, 51, 41, 66, 75, 57, 63], [26, 26, 34, 30, 22, 10, 18, 23], [18, 15, 14, 27, 11, 14, 23, 12]).  splitting further ...
#
# splitting ... with seed: 131
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([61, 65, 64, 48, 56, 71, 39, 54], [20, 14, 11, 18, 28, 7, 38, 14], [17, 19, 23, 33, 15, 21, 22, 30]).  splitting further ...
#
# splitting ... with seed: 132
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([54, 62, 53, 67, 77, 64, 59, 67], [24, 17, 24, 18, 10, 17, 29, 20], [21, 20, 22, 13, 12, 17, 11, 11]).  splitting further ...
#
# splitting ... with seed: 133
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([58, 55, 60, 68, 27, 75, 69, 58], [25, 24, 29, 15, 61, 21, 21, 24], [16, 19, 9, 15, 11, 3, 9, 17]).  splitting further ...
#
# splitting ... with seed: 134
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([63, 55, 71, 63, 70, 64, 23, 53], [16, 20, 14, 14, 17, 7, 32, 27], [19, 23, 14, 21, 12, 28, 43, 18]).  splitting further ...
#
# splitting ... with seed: 135
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([61, 58, 56, 61, 58, 53, 59, 58], [22, 25, 27, 22, 33, 21, 26, 25], [16, 16, 16, 15, 7, 25, 14, 15]).  splitting further ...
#
# splitting ... with seed: 136
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([60, 56, 66, 71, 68, 78, 56, 61], [22, 23, 13, 19, 28, 7, 23, 27], [16, 20, 19, 8, 2, 14, 19, 11]).  splitting further ...
#
# splitting ... with seed: 137
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([70, 64, 70, 56, 65, 53, 53, 64], [14, 19, 18, 21, 22, 10, 22, 14], [15, 15, 11, 22, 12, 35, 23, 21]).  splitting further ...
#
# splitting ... with seed: 138
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([59, 60, 55, 54, 53, 89, 59, 71], [21, 16, 27, 22, 30], [19, 22, 16, 23, 16, 10, 30, 17]).  splitting further ...
#
# splitting ... with seed: 139
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([57, 57, 55, 61, 35, 39, 88, 58], [22, 24, 16, 13, 32, 7, 1, 12], [20, 18, 27, 25, 32, 53, 9, 28]).  splitting further ...
#
# splitting ... with seed: 140
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([61, 51, 66, 65, 32, 42, 59, 47], [20, 24, 17, 24, 27, 35, 22, 30], [18, 23, 15, 10, 40, 21, 18, 21]).  splitting further ...
#
# splitting ... with seed: 141
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([63, 67, 63, 68, 48, 64, 40, 62], [16, 13, 16, 13, 35, 17, 47, 17], [20, 18, 20, 18, 16, 17, 11, 20]).  splitting further ...
#
# splitting ... with seed: 142
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([60, 50, 55, 59, 83, 71, 50, 58], [20, 27, 26, 18, 12, 7, 33, 20], [19, 21, 18, 22, 3, 21, 15, 20]).  splitting further ...
#
# splitting ... with seed: 143
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([55, 61, 56, 53, 43, 42, 63, 52], [19, 17, 14, 20, 32, 25, 25, 23], [24, 21, 28, 25, 23, 32, 11, 23]).  splitting further ...
#
# splitting ... with seed: 144
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([63, 60, 63, 56, 82, 82, 49, 60], [21, 21, 17, 19, 15, 10, 35, 24], [15, 18, 18, 23, 2, 7, 15, 14]).  splitting further ...
#
# splitting ... with seed: 145
# Done
#
# result:  (False, False, True)
# plos_pubmed split is not yet balanced ([60, 67, 68, 63, 55, 71, 85, 63], [21, 18, 17, 17, 18], [18, 14, 14, 18, 26, 28, 9, 19]).  splitting further ...
#
# splitting ... with seed: 146
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([63, 63, 68, 58, 80, 75, 61, 62], [20, 22, 21, 19, 5, 10, 32, 19], [16, 13, 10, 22, 15, 14, 5, 17]).  splitting further ...
#
# splitting ... with seed: 147
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([63, 59, 67, 70, 68, 64, 71, 64], [18, 20, 21, 17, 5, 3, 15, 15], [17, 20, 11, 12, 26, 32, 12, 19]).  splitting further ...
#
# splitting ... with seed: 148
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([61, 44, 65, 68, 55, 82, 59, 58], [19, 28, 14, 17, 17], [19, 27, 20, 14, 27, 17, 19, 20]).  splitting further ...
#
# splitting ... with seed: 149
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([62, 66, 69, 60, 62, 57, 54, 69], [15, 21, 14, 18, 27, 17, 14, 17], [21, 11, 15, 21, 10, 25, 30, 13]).  splitting further ...
#
# splitting ... with seed: 150
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([63, 69, 64, 62, 66, 82, 67, 57], [14, 16, 9, 16, 13], [21, 14, 26, 21, 20, 17, 15, 17]).  splitting further ...
#
# splitting ... with seed: 151
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([57, 67, 51, 55, 61, 75, 57, 71], [22, 17, 24, 25, 30, 3, 29, 12], [19, 15, 24, 18, 8, 21, 12, 15]).  splitting further ...
#
# splitting ... with seed: 152
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([60, 56, 68, 66, 67, 32, 49, 56], [18, 19, 11, 14, 12, 50, 25, 24], [21, 24, 20, 18, 20, 17, 25, 18]).  splitting further ...
#
# splitting ... with seed: 153
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([56, 68, 55, 60, 35, 46, 50, 58], [22, 11, 12, 21, 12, 28, 29, 27], [20, 19, 32, 17, 52, 25, 19, 14]).  splitting further ...
#
# splitting ... with seed: 154
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([59, 59, 68, 57, 38, 57, 45, 61], [22, 23, 14, 21, 30, 7, 29, 18], [18, 17, 17, 21, 31, 35, 25, 19]).  splitting further ...
#
# splitting ... with seed: 155
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([58, 58, 63, 54, 51, 32, 57, 65], [20, 21, 22, 29, 35, 25, 33, 15], [21, 20, 14, 16, 13, 42, 8, 18]).  splitting further ...
#
# splitting ... with seed: 156
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([60, 64, 70, 56, 42, 50, 66, 63], [18, 13, 12, 23, 47, 25, 12, 20], [21, 21, 16, 19, 10, 25, 21, 16]).  splitting further ...
#
# splitting ... with seed: 157
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([61, 70, 55, 59, 73, 50, 78, 60], [20, 13, 30, 18, 8, 32, 1, 21], [18, 15, 14, 21, 17, 17, 19, 17]).  splitting further ...
#
# splitting ... with seed: 158
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([60, 64, 62, 58, 73, 57, 47, 65], [16, 20, 17, 25, 20, 35, 29, 16], [23, 15, 20, 16, 6, 7, 22, 17]).  splitting further ...
#
# splitting ... with seed: 159
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([57, 61, 60, 62, 48, 67, 69, 54], [19, 14, 13, 9, 26, 17, 22, 18], [23, 23, 25, 28, 25, 14, 8, 26]).  splitting further ...
#
# splitting ... with seed: 160
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([55, 55, 52, 52, 47, 28, 52, 60], [25, 21, 29, 23, 12, 25, 18, 19], [18, 22, 17, 23, 40, 46, 29, 19]).  splitting further ...
#
# splitting ... with seed: 161
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([60, 60, 63, 66, 71, 85, 63, 58], [19, 19, 19, 18, 7, 10, 18, 28], [20, 19, 17, 14, 21, 3, 18, 12]).  splitting further ...
#
# splitting ... with seed: 162
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([57, 61, 52, 57, 56, 82, 69, 65], [22, 7, 24, 19, 11, 7, 9, 18], [20, 30, 22, 23, 32, 10, 21, 15]).  splitting further ...
#
# splitting ... with seed: 163
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([54, 56, 50, 55, 63, 50, 56, 56], [24, 25, 23, 25, 17, 28, 21, 38], [20, 17, 26, 18, 18, 21, 22, 5]).  splitting further ...
#
# splitting ... with seed: 164
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([59, 66, 54, 64, 66, 46, 52, 63], [24, 17, 26, 18, 18, 21, 19, 20], [16, 15, 19, 16, 15, 32, 28, 16]).  splitting further ...
#
# splitting ... with seed: 165
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([62, 60, 62, 62, 63, 60, 40, 53], [17, 15, 18, 20, 6, 17, 23, 17], [19, 23, 18, 17, 30, 21, 35, 29]).  splitting further ...
#
# splitting ... with seed: 166
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([60, 67, 57, 62, 76, 64, 70, 64], [17, 14, 14, 13, 6, 17, 29, 21], [22, 18, 27, 24, 17, 17]).  splitting further ...
#
# splitting ... with seed: 167
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([61, 65, 65, 53, 52, 39, 40, 61], [21, 15, 11, 23, 26, 17, 35, 18], [17, 19, 23, 22, 21, 42, 23, 19]).  splitting further ...
#
# splitting ... with seed: 168
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([60, 72, 68, 55, 46, 67, 38, 60], [19, 13, 15, 25, 25, 14, 36, 19], [20, 14, 16, 18, 28, 17, 25, 19]).  splitting further ...
#
# splitting ... with seed: 169
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([58, 61, 50, 62, 82, 67, 66, 40], [16, 14, 17, 11, 5, 7, 7, 17], [24, 23, 32, 25, 12, 25, 26, 42]).  splitting further ...
#
# splitting ... with seed: 170
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([60, 61, 58, 68, 50, 53, 35, 64], [20, 17, 20, 18, 17, 17, 25, 11], [18, 20, 21, 13, 32, 28, 39, 23]).  splitting further ...
#
# splitting ... with seed: 171
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([62, 61, 63, 56, 55, 75, 76, 65], [16, 17, 16, 25, 10, 7, 14, 17], [21, 21, 19, 17, 35, 17, 9, 16]).  splitting further ...
#
# splitting ... with seed: 172
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([64, 62, 66, 63, 86, 89, 59, 72], [16, 22, 15, 19, 5], [19, 15, 17, 16, 8, 10, 15, 11]).  splitting further ...
#
# splitting ... with seed: 173
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([63, 54, 56, 58, 76, 57, 39, 47], [18, 19, 16, 14, 12], [17, 26, 26, 26, 11, 42, 29, 35]).  splitting further ...
#
# splitting ... with seed: 174
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([59, 60, 57, 71, 57, 57, 35, 52], [19, 22, 28, 12, 25, 7, 43, 22], [21, 16, 14, 16, 17, 35, 21, 25]).  splitting further ...
#
# splitting ... with seed: 175
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([59, 57, 51, 63, 76, 75, 50, 68], [21, 16, 24, 25, 17, 25, 22, 15], [19, 25, 24, 10, 6]).  splitting further ...
#
# splitting ... with seed: 176
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([59, 58, 61, 59, 52, 57, 63, 69], [18, 23, 12, 21, 13, 17, 22, 15], [22, 17, 26, 18, 33, 25, 14, 15]).  splitting further ...
#
# splitting ... with seed: 177
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([59, 53, 63, 66, 31, 32, 59, 63], [21, 20, 14, 17, 55, 57, 29, 22], [19, 26, 21, 15, 13, 10, 11, 14]).  splitting further ...
#
# splitting ... with seed: 178
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([60, 54, 57, 63, 82, 78, 70, 63], [21, 23, 23, 19, 11, 14, 14, 17], [18, 21, 19, 16, 6, 7, 15, 18]).  splitting further ...
#
# splitting ... with seed: 179
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([63, 61, 68, 61, 57, 75, 74, 53], [19, 20, 16, 24, 36], [17, 18, 15, 13, 6, 25, 5, 17]).  splitting further ...
#
# splitting ... with seed: 180
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([59, 61, 54, 54, 46, 71, 66, 63], [21, 19, 29, 26, 21, 17, 9, 15], [19, 18, 15, 19, 32, 10, 23, 21]).  splitting further ...
#
# splitting ... with seed: 181
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([64, 66, 69, 72, 53, 57, 46, 76], [15, 19, 13, 12, 33, 17, 22, 6], [19, 14, 16, 14, 12, 25, 30, 16]).  splitting further ...
#
# splitting ... with seed: 182
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([56, 55, 60, 51, 56, 64, 50, 52], [19, 23, 14, 16, 35, 7, 19, 18], [23, 20, 24, 31, 8, 28, 29, 29]).  splitting further ...
#
# splitting ... with seed: 183
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([58, 69, 56, 51, 83, 39, 64, 52], [22, 20, 22, 27, 10, 14, 22, 29], [19, 9, 21, 20, 6, 46, 12, 18]).  splitting further ...
#
# splitting ... with seed: 184
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([65, 54, 62, 70, 75, 64, 78, 62], [16, 16, 23, 11, 10, 14, 1, 24], [18, 29, 13, 17, 15, 21, 19, 12]).  splitting further ...
#
# splitting ... with seed: 185
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([62, 69, 51, 62, 78, 67, 73, 58], [21, 21, 26, 26, 5, 28, 18, 23], [15, 8, 22, 10, 16, 3, 8, 17]).  splitting further ...
#
# splitting ... with seed: 186
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([62, 63, 66, 58, 66, 82, 59, 56], [17, 18, 11, 15, 11, 14, 18, 22], [20, 17, 22, 25, 22, 3, 22, 21]).  splitting further ...
#
# splitting ... with seed: 187
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([60, 63, 47, 45, 32, 57, 47, 52], [20, 18, 31, 31, 57, 3, 38, 22], [18, 17, 21, 22, 10, 39, 14, 25]).  splitting further ...
#
# splitting ... with seed: 188
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([66, 56, 73, 68, 58, 78, 60, 52], [14, 16, 9, 15, 12, 17, 18, 27], [18, 26, 17, 15, 28, 3, 21, 19]).  splitting further ...
#
# splitting ... with seed: 189
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([57, 68, 62, 69, 47, 92, 76, 65], [20, 17, 21, 17, 38, 3, 4, 9], [22, 14, 16, 13, 13, 3, 19, 24]).  splitting further ...
#
# splitting ... with seed: 190
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([61, 49, 63, 62, 47, 60, 50, 43], [20, 28, 11, 18, 35, 14, 33, 28], [18, 21, 25, 18, 17, 25, 15, 28]).  splitting further ...
#
# splitting ... with seed: 191
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([59, 65, 67, 63, 66, 60, 54, 49], [17, 15, 15, 17, 20, 14, 32, 27], [23, 19, 17, 18, 13, 25, 12, 23]).  splitting further ...
#
# splitting ... with seed: 192
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([61, 61, 54, 66, 32, 60, 73, 65], [19, 18, 11, 15, 31, 32, 14, 12], [19, 20, 33, 17, 36, 7, 12, 21]).  splitting further ...
#
# splitting ... with seed: 193
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([68, 68, 62, 64, 33, 39, 53, 57], [15, 16, 12, 14, 48, 32, 25, 15], [16, 15, 24, 20, 17, 28, 21, 27]).  splitting further ...
#
# splitting ... with seed: 194
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([62, 67, 65, 50, 66, 53, 67, 63], [19, 15, 21, 24, 5, 25, 29, 13], [17, 16, 12, 25, 28, 21, 2, 23]).  splitting further ...
#
# splitting ... with seed: 195
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([58, 62, 63, 59, 53, 42, 52, 47], [20, 19, 14, 18, 10, 10, 30, 25], [21, 18, 21, 22, 36, 46, 16, 27]).  splitting further ...
#
# splitting ... with seed: 196
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([57, 53, 52, 55, 71, 50, 45, 54], [17, 19, 15, 13, 12, 21, 42, 17], [24, 26, 31, 31, 16, 28, 12, 28]).  splitting further ...
#
# splitting ... with seed: 197
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([54, 57, 56, 55, 71, 50, 64, 52], [25, 27, 28, 18, 22, 10, 29, 23], [20, 15, 14, 25, 6, 39, 5, 23]).  splitting further ...
#
# splitting ... with seed: 198
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([61, 63, 65, 74, 85, 67, 54, 58], [18, 15, 14, 11, 8, 17, 22, 23], [20, 21, 20, 14, 6, 14, 22, 18]).  splitting further ...
#
# splitting ... with seed: 199
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([64, 62, 76, 74, 47, 85, 43, 70], [13, 20, 9, 14, 13, 3, 22, 17], [21, 17, 13, 10, 38, 10, 33, 12]).  splitting further ...
#
# splitting ... with seed: 200
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([62, 56, 68, 70, 48, 64, 70, 64], [15, 23, 15, 17, 25, 10, 16, 8], [22, 19, 15, 12, 26, 25, 12, 26]).  splitting further ...
#
# splitting ... with seed: 201
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([54, 65, 57, 59, 65, 46, 56, 59], [24, 14, 28, 25, 13, 17, 11, 20], [20, 20, 14, 14, 21, 35, 32, 19]).  splitting further ...
#
# splitting ... with seed: 202
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([61, 54, 65, 62, 67, 92, 66, 33], [18, 25, 17, 12, 21], [19, 20, 17, 24, 11, 7, 19, 52]).  splitting further ...
#
# splitting ... with seed: 203
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([57, 55, 61, 58, 62, 57, 61, 48], [23, 21, 22, 17, 11, 10, 16, 19], [18, 23, 16, 24, 26, 32, 21, 31]).  splitting further ...
#
# splitting ... with seed: 204
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([59, 64, 61, 72, 62, 53, 85, 72], [18, 18, 15, 14, 6, 39, 4, 15], [22, 17, 22, 13, 31, 7, 9, 11]).  splitting further ...
#
# splitting ... with seed: 205
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([57, 55, 45, 55, 68, 50, 67, 70], [19, 28, 20, 15, 8, 32, 15, 14], [22, 16, 34, 28, 22, 17, 16, 14]).  splitting further ...
#
# splitting ... with seed: 206
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([59, 67, 61, 57, 47, 39, 67, 58], [18, 7, 17, 28, 20, 53, 18, 24], [21, 25, 21, 14, 32, 7, 14, 17]).  splitting further ...
#
# splitting ... with seed: 207
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([56, 63, 52, 54, 56, 57, 47, 64], [17, 17, 20, 22, 17, 3, 36, 13], [26, 18, 27, 23, 26, 39, 15, 22]).  splitting further ...
#
# splitting ... with seed: 208
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([59, 63, 59, 56, 42, 57, 61, 61], [19, 20, 19, 23, 28, 32, 18, 23], [20, 15, 21, 19, 28, 10, 19, 15]).  splitting further ...
#
# ...
#
# splitting ... with seed: 799
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([58, 56, 57, 57, 56, 64, 50, 66], [19, 23, 17, 25, 31, 25, 12, 17], [21, 19, 25, 17, 12, 10, 36, 16]).  splitting further ...
#
# splitting ... with seed: 800
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([57, 66, 52, 59, 38, 53, 50, 64], [19, 15, 24, 24, 32, 14, 43, 23], [23, 18, 22, 16, 28, 32, 5, 11]).  splitting further ...
#
# splitting ... with seed: 801
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([57, 67, 59, 57, 83, 60, 60, 53], [24, 16, 20, 16, 8, 17, 23, 23], [18, 16, 19, 25, 7, 21, 15, 22]).  splitting further ...
#
# splitting ... with seed: 802
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([58, 50, 52, 62, 28, 42, 71, 56], [19, 28, 26, 15, 30, 28, 11, 23], [22, 21, 20, 22, 41, 28, 16, 19]).  splitting further ...
#
# splitting ... with seed: 803
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([57, 63, 55, 51, 75, 57, 60, 70], [18, 13, 11, 11, 12, 7, 15, 16], [24, 22, 33, 37, 12, 35, 23, 13]).  splitting further ...
#
# splitting ... with seed: 804
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([54, 53, 44, 52, 30, 71, 73, 45], [23, 23, 30, 30, 32, 21, 14, 35], [22, 23, 24, 17, 37, 7, 12, 19]).  splitting further ...
#
# splitting ... with seed: 805
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([56, 58, 42, 52, 56, 92, 52, 65], [21, 17, 38, 19, 1], [21, 23, 18, 27, 42, 7, 14, 20]).  splitting further ...
#
# splitting ... with seed: 806
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([66, 67, 70, 66, 55, 39, 45, 56], [18, 13, 19, 20, 15, 53, 12, 25], [15, 19, 10, 12, 30, 7, 42, 17]).  splitting further ...
#
# splitting ... with seed: 807
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([57, 59, 72, 60, 48, 50, 38, 60], [21, 21, 14, 21, 23, 17, 15, 11], [20, 19, 12, 17, 27, 32, 46, 28]).  splitting further ...
#
# splitting ... with seed: 808
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([62, 45, 60, 65, 52, 64, 59, 61], [17, 24, 21, 14, 12, 14, 12, 17], [19, 29, 17, 19, 35, 21, 28, 21]).  splitting further ...
#
# splitting ... with seed: 809
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([63, 55, 64, 56, 45, 42, 42, 52], [16, 21, 22, 22, 25], [19, 22, 13, 20, 30, 57, 39, 31]).  splitting further ...
#
# splitting ... with seed: 810
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([62, 56, 58, 64, 70, 82, 64, 60], [16, 23, 18, 19, 15, 7, 14, 14], [21, 19, 22, 15, 15, 10, 21, 24]).  splitting further ...
#
# splitting ... with seed: 811
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([60, 57, 51, 66, 52, 53, 70, 62], [21, 22, 28, 16, 27, 14, 8, 17], [18, 19, 20, 17, 20, 32, 21, 19]).  splitting further ...
#
# splitting ... with seed: 812
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([63, 60, 70, 66, 57, 71, 64, 56], [16, 15, 15, 14, 15, 7, 12, 25], [19, 23, 14, 19, 27, 21, 22, 17]).  splitting further ...
#
# splitting ... with seed: 813
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([60, 58, 58, 60, 47, 64, 54, 75], [16, 22, 19, 22, 6, 25, 32, 7], [23, 18, 22, 17, 46, 10, 12, 17]).  splitting further ...
#
# splitting ... with seed: 814
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([57, 56, 66, 74, 82, 67, 30, 52], [21, 30, 16, 10, 8, 28, 39, 18], [20, 13, 17, 15, 8, 3, 29, 28]).  splitting further ...
#
# splitting ... with seed: 815
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([63, 56, 67, 60, 67, 57, 77, 54], [17, 23, 14, 16, 6, 10, 7, 18], [18, 19, 18, 23, 26, 32, 15, 26]).  splitting further ...
#
# splitting ... with seed: 816
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([64, 52, 61, 53, 43, 71, 70, 52], [15, 25, 12, 19, 28, 14, 11, 21], [19, 22, 25, 26, 27, 14, 18, 26]).  splitting further ...
#
# splitting ... with seed: 817
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([64, 55, 62, 65, 76, 71, 38, 60], [18, 23, 20, 17, 12, 21, 32, 23], [16, 21, 17, 17, 11, 7, 29, 16]).  splitting further ...
#
# splitting ... with seed: 818
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([56, 52, 57, 58, 67, 50, 45, 70], [23, 28, 19, 29, 25, 17, 46, 18], [19, 19, 23, 11, 7, 32, 8, 11]).  splitting further ...
#
# splitting ... with seed: 819
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([55, 63, 43, 62, 48, 46, 53, 55], [25, 21, 39, 26, 13, 10, 12, 22], [19, 14, 17, 10, 37, 42, 33, 22]).  splitting further ...
#
# splitting ... with seed: 820
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([64, 50, 57, 59, 77, 71, 73, 68], [15, 24, 11, 29, 8, 21, 21, 19], [20, 24, 30, 11, 13, 7, 5, 11]).  splitting further ...
#
# splitting ... with seed: 821
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([58, 54, 51, 51, 50, 50, 63, 62], [19, 21, 22, 41, 25, 10, 30, 14], [22, 23, 26, 6, 25, 39, 5, 23]).  splitting further ...
#
# splitting ... with seed: 822
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([63, 59, 57, 47, 71, 85, 56, 64], [21, 21, 22, 28, 7, 14, 8, 11], [14, 19, 20, 23, 21]).  splitting further ...
#
# splitting ... with seed: 823
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([60, 58, 63, 62, 38, 50, 67, 71], [19, 19, 13, 11, 31, 35, 12, 16], [20, 21, 22, 26, 30, 14, 19, 11]).  splitting further ...
#
# splitting ... with seed: 824
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([57, 58, 54, 60, 62, 78, 47, 70], [19, 20, 21, 18, 7, 7, 38, 11], [22, 21, 24, 20, 30, 14, 14, 17]).  splitting further ...
#
# splitting ... with seed: 825
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([62, 52, 64, 77, 77, 53, 42, 63], [18, 27, 14, 11, 13, 3, 36, 22], [18, 19, 20, 11, 8, 42, 21, 14]).  splitting further ...
#
# splitting ... with seed: 826
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([59, 52, 66, 53, 62, 71, 54, 38], [20, 29, 18, 23, 23, 21, 19, 26], [19, 17, 14, 22, 13, 7, 25, 35]).  splitting further ...
#
# splitting ... with seed: 827
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([55, 60, 45, 49, 47, 57, 59, 55], [20, 23, 20, 25, 25, 25, 25, 18], [23, 15, 33, 24, 27, 17, 15, 25]).  splitting further ...
#
# splitting ... with seed: 828
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([53, 55, 45, 59, 65, 64, 49, 62], [22, 26, 24, 15, 30, 17, 8, 14], [23, 18, 30, 24, 5, 17, 42, 23]).  splitting further ...
#
# splitting ... with seed: 829
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([60, 59, 63, 55, 57, 57, 69, 47], [16, 19, 8, 13, 11, 10, 5, 16], [23, 20, 27, 30, 31, 32, 25, 35]).  splitting further ...
#
# splitting ... with seed: 830
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([62, 55, 65, 66, 68, 89, 69, 57], [20, 26, 21, 17, 13, 7, 18, 27], [17, 18, 13, 15, 17, 3, 12, 15]).  splitting further ...
#
# splitting ... with seed: 831
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([56, 62, 64, 53, 43, 32, 57, 60], [20, 21, 19, 18, 36, 32, 28, 17], [22, 15, 16, 27, 20, 35, 14, 22]).  splitting further ...
#
# splitting ... with seed: 832
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([54, 63, 44, 50, 70, 46, 46, 58], [25, 19, 34, 23, 18, 35, 47, 17], [19, 17, 20, 25, 11, 17, 5, 23]).  splitting further ...
#
# splitting ... with seed: 833
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([56, 57, 59, 67, 85, 57, 60, 66], [17, 21, 12, 10, 8, 10, 4, 12], [25, 21, 28, 22, 6, 32, 35, 20]).  splitting further ...
#
# splitting ... with seed: 834
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([65, 53, 56, 76, 42, 85, 50, 69], [20, 24, 24, 12, 41, 7, 25, 20], [14, 21, 19, 11, 16, 7, 23, 10]).  splitting further ...
#
# splitting ... with seed: 835
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([56, 53, 45, 51, 85, 57, 60, 50], [19, 30, 22, 25, 8, 32, 7, 29], [23, 16, 32, 22, 6, 10, 32, 20]).  splitting further ...
#
# splitting ... with seed: 836
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([57, 71, 60, 63, 51, 53, 64, 58], [17, 10, 12, 11, 8, 21, 25, 17], [25, 17, 26, 25, 40, 25, 9, 24]).  splitting further ...
#
# splitting ... with seed: 837
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([61, 66, 64, 66, 67, 60, 61, 58], [21, 19, 19, 23, 20, 32, 35, 17], [17, 14, 15, 10, 12, 7, 2, 23]).  splitting further ...
#
# splitting ... with seed: 838
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([61, 66, 65, 62, 50, 32, 61, 43], [22, 19, 22, 21, 11, 57, 14, 34], [15, 13, 11, 15, 38, 10, 23, 22]).  splitting further ...
#
# splitting ... with seed: 839
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([52, 54, 55, 56, 66, 67, 50, 64], [22, 21, 18, 18, 21, 14, 19, 5], [25, 23, 25, 24, 12, 17, 29, 29]).  splitting further ...
#
# splitting ... with seed: 840
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([55, 60, 49, 56, 71, 78, 69, 47], [21, 16, 23, 24, 18, 14, 26, 14], [23, 22, 26, 18, 10, 7, 4, 37]).  splitting further ...
#
# splitting ... with seed: 841
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([60, 69, 60, 64, 42, 89, 80, 64], [23, 20, 26, 15, 43, 7, 14, 19], [15, 10, 12, 19, 13, 3, 5, 15]).  splitting further ...
#
# splitting ... with seed: 842
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([59, 58, 46, 41, 73, 71, 73, 66], [25, 26, 34, 34, 16, 7, 18, 18], [15, 15, 19, 23, 10, 21, 8, 14]).  splitting further ...
#
# splitting ... with seed: 843
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([61, 65, 56, 56, 58, 50, 53, 63], [18, 18, 20, 21, 32, 21, 29, 19], [20, 16, 23, 21, 8, 28, 16, 17]).  splitting further ...
#
# splitting ... with seed: 844
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([55, 62, 57, 61, 78, 75, 33, 53], [23, 26, 16, 12, 8, 25, 26, 26], [20, 10, 26, 25, 12]).  splitting further ...
#
# splitting ... with seed: 845
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([55, 51, 47, 53, 77, 75, 53, 55], [23, 18, 26, 23, 8, 17, 14, 15], [21, 30, 25, 22, 13, 7, 32, 29]).  splitting further ...
#
# splitting ... with seed: 846
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([59, 55, 67, 46, 46, 57, 69, 53], [23, 17, 23, 26, 27, 10, 15, 18], [16, 27, 9, 26, 26, 32, 15, 27]).  splitting further ...
#
# splitting ... with seed: 847
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([59, 71, 61, 61, 53, 35, 49, 60], [15, 18, 13, 15, 30, 3, 19, 17], [25, 9, 25, 22, 16, 60, 30, 22]).  splitting further ...
#
# splitting ... with seed: 848
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([58, 70, 56, 59, 48, 42, 76, 59], [21, 10, 25, 18, 15, 35, 16, 22], [19, 18, 18, 22, 36, 21, 7, 17]).  splitting further ...
#
# splitting ... with seed: 849
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([58, 56, 51, 44, 60, 53, 64, 44], [20, 14, 20, 37, 26, 21, 14, 17], [21, 29, 28, 18, 13, 25, 21, 38]).  splitting further ...
#
# splitting ... with seed: 850
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([60, 51, 60, 62, 53, 78, 46, 47], [16, 24, 17, 25, 16, 10, 26, 23], [22, 24, 22, 12, 30, 10, 26, 29]).  splitting further ...
#
# splitting ... with seed: 851
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([57, 57, 54, 59, 31, 60, 64, 48], [19, 19, 21, 16, 37, 10, 23, 19], [23, 23, 23, 23, 31, 28, 11, 31]).  splitting further ...
#
# splitting ... with seed: 852
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([59, 68, 51, 54, 57, 35, 54, 68], [19, 17, 20, 22, 26, 28, 15, 15], [20, 14, 27, 22, 16, 35, 29, 16]).  splitting further ...
#
# splitting ... with seed: 853
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([55, 73, 57, 57, 48, 46, 49, 64], [23, 13, 22, 22, 10, 39, 21, 27], [20, 13, 20, 19, 41, 14, 29, 7]).  splitting further ...
#
# splitting ... with seed: 854
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([62, 52, 56, 64, 71, 75, 39, 63], [21, 29, 30, 21, 8, 14, 29, 23], [15, 18, 13, 13, 20, 10, 30, 13]).  splitting further ...
#
# splitting ... with seed: 855
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([60, 65, 66, 63, 38, 57, 49, 71], [22, 21, 21, 25, 32, 32, 18, 19], [17, 13, 11, 11, 28, 10, 32, 8]).  splitting further ...
#
# splitting ... with seed: 856
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([58, 57, 55, 58, 45, 57, 67, 55], [19, 22, 20, 26, 10, 14, 16, 30], [21, 19, 23, 14, 45, 28, 15, 13]).  splitting further ...
#
# splitting ... with seed: 857
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([62, 58, 59, 56, 43, 67, 69, 58], [15, 14, 24, 22, 18, 14, 9, 21], [22, 26, 15, 21, 37, 17, 21, 19]).  splitting further ...
#
# splitting ... with seed: 858
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([55, 58, 56, 46, 53, 67, 57, 64], [20, 17, 24, 21, 11, 3, 25, 13], [23, 24, 19, 32, 35, 28, 16, 21]).  splitting further ...
#
# splitting ... with seed: 859
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([62, 61, 58, 54, 46, 50, 57, 49], [17, 16, 19, 20, 23, 28, 15, 28], [20, 21, 21, 24, 30, 21, 26, 22]).  splitting further ...
#
# splitting ... with seed: 860
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([62, 51, 64, 64, 62, 35, 53, 47], [17, 23, 14, 15, 6, 35, 23, 38], [20, 25, 20, 19, 31, 28, 22, 14]).  splitting further ...
#
# splitting ... with seed: 861
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([61, 55, 63, 55, 75, 82, 50, 70], [17, 19, 15, 11, 7, 3, 9, 12], [21, 25, 20, 32, 17, 14, 39, 16]).  splitting further ...
#
# splitting ... with seed: 862
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([64, 58, 58, 63, 83, 53, 42, 67], [21, 23, 25, 18, 6, 39, 36, 15], [13, 17, 16, 17, 10, 7, 21, 17]).  splitting further ...
#
# splitting ... with seed: 863
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([61, 67, 64, 67, 37, 53, 70, 66], [18, 19, 12, 7, 46, 14, 14, 17], [19, 12, 22, 24, 16, 32, 15, 16]).  splitting further ...
#
# splitting ... with seed: 864
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([68, 65, 71, 67, 51, 42, 77, 60], [15, 14, 10, 9, 35, 21, 16, 19], [16, 19, 17, 23, 13, 35, 5, 19]).  splitting further ...
#
# splitting ... with seed: 865
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([57, 60, 62, 51, 48, 50, 40, 75], [22, 22, 23, 28, 12, 35, 21, 13], [19, 17, 14, 20, 38, 14, 38, 11]).  splitting further ...
#
# splitting ... with seed: 866
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([60, 59, 66, 59, 65, 71, 60, 58], [20, 19, 15, 17, 12, 17, 22, 22], [19, 21, 17, 23, 22, 10, 16, 19]).  splitting further ...
#
# splitting ... with seed: 867
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([63, 58, 62, 59, 53, 82, 77, 66], [23, 25, 24, 18, 28, 10, 8, 18], [13, 16, 12, 22, 17, 7, 14, 14]).  splitting further ...
#
# splitting ... with seed: 868

# %%
in_path_comb = '/home/beck/Desktop/Otimal_split/plos_pubmed_combined_bio/'
out_path_comb = '/home/beck/Desktop/Otimal_split/plos_pubmed_combined/'

#split_data(in_path_comb, out_path_comb, 204)


comb_path_whole = '/home/beck/Desktop/Otimal_split/plos_pubmed_combined_bio/'
comb_path_train = "/home/beck/Desktop/Otimal_split/plos_pubmed_combined/plos_pubmed_combined_bio_train/" 
comb_path_test = "/home/beck/Desktop/Otimal_split/plos_pubmed_combined/plos_pubmed_combined_bio_test/" 
comb_path_dev = "/home/beck/Desktop/Otimal_split/plos_pubmed_combined/plos_pubmed_combined_bio_devel/"
    
    
#calculate the distribution of class_labels for cmbined set
comb_whole_dict, comb_train_dict, comb_test_dict, comb_dev_dict = train_test_dev(comb_path_whole, 
                                                                                 comb_path_train, 
                                                                                 comb_path_test, 
                                                                                 comb_path_dev)


# calculate the proportion for each class label (8 - purposes)
comb_train_props, comb_dev_props, comb_test_props = __proportion_calculator(comb_whole_dict, 
                                                                            comb_train_dict, 
                                                                            comb_test_dict, 
                                                                            comb_dev_dict)

comb_train_result_ = _within_range_pubmed(comb_train_props)
comb_test_result_  = _within_range_dev_test(comb_test_props)
comb_dev_result_   = _within_range_dev_test(comb_dev_props)


print(f'plos+pubmed train {comb_train_props, _within_range(comb_train_props)[1]}')
print(f'plos+pubmed test  {comb_test_props, _within_range_dev_test(comb_test_props)[1]}')
print(f'plos+pubmed dev   {comb_dev_props, _within_range_dev_test(comb_dev_props)[1]}')
print()

print(f"plos+pubmed train within +/- 60% ? {_within_range(comb_train_props)[0]}")
print(f"plos+pubmed test  within +/- 15% ? {_within_range_dev_test(comb_test_props)[0]}")
print(f"plos+pubmed dev   within +/- 15% ? {_within_range_dev_test(comb_dev_props)[0]}")
print()

# train percentage 60%
    
for (k,v), (k2,v2) in zip(comb_whole_dict.items(),  comb_train_dict.items()):
    if k2 == k:
        print(f"{k2 :{18}}  {v2}/{v} train {v2/v*100: .2f}% ")

# test percentage 20% 
print()

for (k,v), (k2,v2) in zip(comb_whole_dict.items(),  comb_test_dict.items()):
    if k2 == k:
        print(f"{k2 :{18}}  {v2}/{v} test {v2/v*100: .2f}% ")
        
# dev percentage 20% 
print()

for (k,v), (k2,v2) in zip(comb_whole_dict.items(),  comb_dev_dict.items()):
    if k2 == k:
        print(f"{k2 :{18}}  {v2}/{v} dev {v2/v*100: .2f}% ")
