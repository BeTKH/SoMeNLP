# %% [markdown]
# # data split

# %%
import os
import argparse
import time
import random
import shutil

from pathlib import Path
from math import ceil

from somenlp.utils import get_time_marker
from somenlp.feature_engineering import calculate_features_parallel


import os
from os import listdir 
from collections import Counter

import os
from os import listdir 
from collections import Counter


in_path = '/home/beck/Desktop/SoMeNLP/data/PLoS_methods_bio/'
out_path = '/home/beck/Desktop/SoMeNLP/data/PLoS_methods/'

def split_data(in_path, out_path, seed_, file_ext =".data.txt", 
               ratio =[60, 20, 20], set_names = ['train', 'devel', 'test'], 
               ):
    
    in_path = in_path.rstrip('/')
    out_path = out_path.rstrip('/')

    if not os.path.isdir(in_path):
        raise(RuntimeError("Input path does not exist"))
        
    if not os.path.isdir(out_path):
        os.mkdir(out_path)
    
    if sum(ratio) != 100:
        raise(RuntimeError("Input ratio {} does not sum to 100".format(ratio)))
    if len(ratio) != len(set_names):
        raise(RuntimeError("Number of ratios and setnames has to match: {} vs {}".format(ratio, set_names)))

    #print("Loading files")
    single_files = list(Path(in_path).rglob('*{}'.format(file_ext)))
    
    all_files = []
    for entry in single_files:
        
        base_file_name = entry.name.split(file_ext)[0]
        
        base_file_entries = list(Path(in_path).rglob('{}*'.format(base_file_name)))
        
        all_files.append(base_file_entries)
    
    random.seed(seed_)
    random.shuffle(all_files)

    #print("Copying files")
    cut_sum = 0
    prev_cut_idx = 0
    for cut, name in zip(ratio, set_names):
        cut_sum += cut
        cut_idx = ceil(len(all_files) * cut_sum / 100) 
        
        out_folder_name = in_path.rsplit('/')[-1]
        new_output_location = '{}/{}_{}'.format(out_path.rstrip('/'), out_folder_name, name) 
        
        if not os.path.isdir(new_output_location):
            os.makedirs(new_output_location)
            
        for files in all_files[prev_cut_idx:cut_idx]:
            for f in files:
                source_path = str(f)
                target_path = '{}/{}'.format(new_output_location, f.name)
                shutil.copy(source_path, target_path)
        prev_cut_idx = cut_idx
    
    print("Done")
    

def purposeLabel_counter(path):
    
    import os
    from os import listdir 
    from collections import Counter
    
    
    def list_file_names(path, file_ext='.labels.txt'):
    
        file_names_list = []

        for file_name in os.listdir(path):
            if not file_name.endswith(file_ext): continue
            file_names_list.append(file_name) 

        file_names_list.sort()

        return file_names_list
    
    file_name_list = list_file_names(path)
    
    interest_list = ["Analysis", "Modelling", "Stimulation", "DataCollection", "DataPreProcss", 
                 "Simulation", "Visualization", "Programming"]
    
    all_purpose_labels = []
    
    for file_name in file_name_list[:]:
        file_path = path + file_name
        
        with open(file_path, 'r') as f:
            
            list_lines = f.readlines()
            
            #print(list_of_lebs)
            list_of_tokens = ' '.join(list_lines).split()
            
            for tok in list_of_tokens:
                if tok != 'O' and (len(tok.split('-')[1].split('_')) == 3 ):
                    if tok.split('-')[1].split('_')[2] in interest_list:
                        
                        purpose = tok.split('-')[1].split('_')[2]
                        
                        all_purpose_labels.append(purpose)
    
                        
    return  dict(Counter(all_purpose_labels))

def train_test_dev(whole_path, train_path, test_path, dev_path):
    
    _whole = purposeLabel_counter(whole_path)
    _train = purposeLabel_counter(train_path)
    _test  = purposeLabel_counter(test_path)
    _dev   = purposeLabel_counter(dev_path)
    
    
    
    _whole_sorted = dict(sorted(_whole.items()))
    _train_sorted = dict(sorted(_train.items()))
    _test_sorted  = dict(sorted(_test.items()))
    _dev_sorted   = dict(sorted(_dev.items()))
    
    return _whole_sorted, _train_sorted, _test_sorted, _dev_sorted

def __proportion_calculator_with_key(whole_dict, train_dict, test_dict, dev_dict ):
    
    train_purpose_props = []
    for (k,v), (k2,v2) in zip(whole_dict.items(), train_dict.items()):
        if k2 == k: 
            train_percentage = int(v2 / v * 100)
            train_purpose_props.append((train_percentage, k))
            
    dev_purpose_props = []
    for (k,v), (k2,v2) in zip(whole_dict.items(), dev_dict.items()):
        if k2 == k:
            
            dev_percentage = int(v2 / v * 100)
            dev_purpose_props.append((dev_percentage,k))
            
    test_purpose_props = []       
    for (k,v), (k2,v2) in zip(whole_dict.items(), test_dict.items()):
        if k2 == k:
            
            test_percentage = int(v2 / v * 100)
            test_purpose_props.append((test_percentage, k))
            
    return train_purpose_props, dev_purpose_props, test_purpose_props


def __proportion_calculator(whole_dict, train_dict, test_dict, dev_dict ):
    
    train_purpose_props = []
    for (k,v), (k2,v2) in zip(whole_dict.items(), train_dict.items()):
        if k2 == k: 
            train_percentage = int(v2 / v * 100)
            train_purpose_props.append(train_percentage)
            
    dev_purpose_props = []
    for (k,v), (k2,v2) in zip(whole_dict.items(), dev_dict.items()):
        if k2 == k:
            
            dev_percentage = int(v2 / v * 100)
            dev_purpose_props.append(dev_percentage)
            
    test_purpose_props = []       
    for (k,v), (k2,v2) in zip(whole_dict.items(), test_dict.items()):
        if k2 == k:
            
            test_percentage = int(v2 / v * 100)
            test_purpose_props.append(test_percentage)
            
    return train_purpose_props, dev_purpose_props, test_purpose_props



def _within_range(list_):
    
    bool_list = []
    for val in list_:
        if val in range(55,65):
            bool_list.append(True)
        else:
            bool_list.append(False)
            
    return all(bool_list) #, bool_list   # apply & to all and return


def _within_range_pubmed(list_):
    
    bool_list = []
    for val in list_:
        if val in range(50,70):
            bool_list.append(True)
        else:
            bool_list.append(False)
            
            
    withn_range_bool = all(bool_list) # apply & to all and return
    
    # check if all class labels are included , class label stimulation is missing in the PubMed 
    if (len(bool_list) == 7):
        all_classes_included = True
    else:
        all_classes_included = False
        
    result = all_classes_included and withn_range_bool
            
    return result   


def _within_range_dev_test(list_):
    
    bool_list = []
    for val in list_:
        if val in range(15,25):
            bool_list.append(True)
        else:
            bool_list.append(False)
            
    return all(bool_list) #, bool_list   # apply & to all and return

# %% [markdown]
# # plos_pubmed_combined

# %%
# combined plos pubmed bio   train , test , dev


in_path_comb = '/home/beck/Desktop/SoMeNLP/data/plos_pubmed_combined_bio/'
out_path_comb = '/home/beck/Desktop/SoMeNLP/data/plos_pubmed_combined/'

stable_split_seeds = [204, 1623, 1686, 2075, 2183, 2665, 2699, 3259, 4680, 4709, 4893, 5648, 7088, 7798,
                     8204, 8990, 9392, 10390, 10790, 11148, 11624, 11701, 12053, 12379]

i = 12545

split_data(in_path_comb, out_path_comb, i)


comb_path_whole = '/home/beck/Desktop/SoMeNLP/data/plos_pubmed_combined_bio/'
comb_path_train = "/home/beck/Desktop/SoMeNLP/data/plos_pubmed_combined/plos_pubmed_combined_bio_train/" 
comb_path_test = "/home/beck/Desktop/SoMeNLP/data/plos_pubmed_combined/plos_pubmed_combined_bio_test/" 
comb_path_dev = "/home/beck/Desktop/SoMeNLP/data/plos_pubmed_combined/plos_pubmed_combined_bio_devel/"
    
    
#calculate the distribution of class_labels for cmbined set
comb_whole_dict, comb_train_dict, comb_test_dict, comb_dev_dict = train_test_dev(comb_path_whole, 
                                                                                 comb_path_train, 
                                                                                 comb_path_test, 
                                                                                 comb_path_dev)


# calculate the proportion for each class label (8 - purposes)
comb_train_props, comb_dev_props, comb_test_props = __proportion_calculator(comb_whole_dict, 
                                                                            comb_train_dict, 
                                                                            comb_test_dict, 
                                                                            comb_dev_dict)


comb_train_result_ = _within_range_pubmed(comb_train_props)
comb_test_result_  = _within_range_dev_test(comb_test_props)
comb_dev_result_   = _within_range_dev_test(comb_dev_props)

bool_ = (comb_train_result_) and (comb_test_result_) and (comb_dev_result_)

stable_split_seeds = []

while not(bool_):
    
    print(f'splitting ... with seed: {i}')
    
    split_data(in_path_comb, out_path_comb, i)
    
    i += 1
    
    
    
    #calculate the distribution of class_labels for cmbined set
    comb_whole_dict, comb_train_dict, comb_test_dict, comb_dev_dict = train_test_dev(comb_path_whole, 
                                                                                 comb_path_train, 
                                                                                 comb_path_test, 
                                                                                 comb_path_dev)


    # calculate the proportion for each class label (8 - purposes)
    comb_train_props, comb_dev_props, comb_test_props = __proportion_calculator(comb_whole_dict, 
                                                                            comb_train_dict, 
                                                                            comb_test_dict, 
                                                                            comb_dev_dict)
    #print('is the split fair ?')
    comb_train_result_ = _within_range(comb_train_props)
    comb_test_result  = _within_range_dev_test(comb_test_props)
    comb_dev_result   = _within_range_dev_test(comb_dev_props)
    print()
    
    bool_ = (comb_train_result_) and (comb_test_result_) and (comb_dev_result_)
    

    
    
    if bool_:
        print()
        print('plos_pubmed split is balanced. stopped splitting')
        print(f'result:  {comb_train_result_, comb_test_result, comb_dev_result}') 
        stable_split_seeds.append(i)
        break
        
    else:
        
        shutil.rmtree(comb_path_train, ignore_errors=False, onerror=None)
        shutil.rmtree(comb_path_test, ignore_errors=False, onerror=None)
        shutil.rmtree(comb_path_dev, ignore_errors=False, onerror=None)
        
        print(f'result:  {comb_train_result_, comb_test_result, comb_dev_result}')   
        print(f'plos_pubmed split is not yet balanced {comb_train_props, comb_dev_props, comb_test_props}.  splitting further ...')
        print()
# Out:
# Done
# splitting ... with seed: 12545
# Done
#
# result:  (False, True, False)
# plos_pubmed split is not yet balanced ([61, 61, 54, 60, 58, 82, 53, 66], [18, 21, 25, 22, 25], [20, 16, 19, 16, 16, 17, 15, 16]).  splitting further ...
#
# splitting ... with seed: 12546
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([57, 60, 67, 60, 42, 57, 52, 74], [19, 9, 10, 13, 26, 32, 25, 9], [23, 30, 22, 25, 31, 10, 22, 16]).  splitting further ...
#
# splitting ... with seed: 12547
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([59, 50, 58, 55, 55, 64, 61, 58], [21, 20, 22, 30, 21, 3, 28, 16], [18, 28, 18, 14, 23, 32, 9, 25]).  splitting further ...
#
# splitting ... with seed: 12548
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([63, 67, 60, 58, 83, 75, 59, 74], [19, 10, 26, 25, 8, 14, 16, 17], [17, 22, 12, 15, 7, 10, 23, 8]).  splitting further ...
#
# splitting ... with seed: 12549
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([64, 67, 65, 56, 78, 67, 66, 77], [21, 15, 22, 14, 12, 17, 19, 10], [14, 17, 11, 29, 8, 14, 14, 11]).  splitting further ...
#
# splitting ... with seed: 12550
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([55, 60, 51, 63, 52, 71, 49, 60], [25, 10, 27, 21, 18, 14, 18, 19], [18, 28, 20, 14, 28, 14, 32, 19]).  splitting further ...
#
# splitting ... with seed: 12551
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([62, 58, 69, 64, 86, 46, 32, 65], [17, 23, 13, 11, 8, 32, 53, 16], [19, 17, 17, 23, 5, 21, 14, 17]).  splitting further ...
#
# splitting ... with seed: 12552
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([62, 58, 53, 62, 67, 42, 73, 66], [17, 21, 20, 20, 25, 28, 12, 13], [20, 20, 25, 16, 7, 28, 14, 19]).  splitting further ...
#
# splitting ... with seed: 12553
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([65, 68, 80, 66, 48, 46, 59, 74], [17, 14, 9, 18, 18, 35, 25, 15], [17, 17, 9, 14, 32, 17, 15, 10]).  splitting further ...
#
# splitting ... with seed: 12554
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([59, 59, 62, 45, 26, 42, 60, 59], [18, 22, 22, 24, 62, 42, 26, 14], [22, 17, 14, 29, 11, 14, 12, 25]).  splitting further ...
#
# splitting ... with seed: 12555
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([63, 64, 62, 62, 51, 46, 77, 67], [17, 13, 19, 18, 25, 25, 8, 17], [19, 21, 17, 18, 23, 28, 14, 14]).  splitting further ...
#
# splitting ... with seed: 12556
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([54, 58, 45, 55, 67, 60, 67, 49], [25, 21, 31, 22, 3, 14, 11, 26], [20, 20, 22, 22, 28, 25, 21, 23]).  splitting further ...
#
# splitting ... with seed: 12557
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([60, 62, 60, 59, 78, 60, 74, 52], [18, 14, 20, 11, 13, 7, 14, 23], [21, 23, 18, 29, 7, 32, 11, 23]).  splitting further ...
#
# splitting ... with seed: 12558
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([61, 55, 61, 59, 77, 50, 63, 68], [19, 22, 18, 24, 12, 42, 11, 26], [19, 21, 19, 15, 10, 7, 25, 5]).  splitting further ...
#
# splitting ... with seed: 12559
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([55, 61, 59, 64, 88, 53, 85, 65], [21, 19, 20, 21, 6, 17, 7, 17], [23, 18, 19, 13, 5, 28, 7, 16]).  splitting further ...
#
# splitting ... with seed: 12560
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([58, 59, 54, 56, 76, 57, 46, 75], [25, 21, 27, 18, 8, 28, 42, 10], [15, 18, 18, 25, 15, 14, 11, 14]).  splitting further ...
#
# splitting ... with seed: 12561
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([57, 60, 56, 60, 75, 67, 63, 58], [19, 23, 16, 20, 12, 17, 23, 17], [22, 15, 26, 19, 12, 14, 12, 24]).  splitting further ...
#
# splitting ... with seed: 12562
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([53, 58, 66, 55, 35, 46, 59, 57], [20, 22, 13, 17, 32, 21, 21, 24], [26, 19, 19, 27, 32, 32, 19, 17]).  splitting further ...
#
# splitting ... with seed: 12563
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([55, 61, 48, 51, 47, 71, 45, 43], [25, 21, 30, 24, 36, 21, 11, 34], [19, 17, 21, 23, 16, 7, 43, 22]).  splitting further ...
#
# splitting ... with seed: 12564
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([61, 64, 63, 62, 50, 46, 59, 61], [19, 12, 18, 11, 18, 42, 8, 12], [18, 22, 17, 26, 31, 10, 32, 25]).  splitting further ...
#
# splitting ... with seed: 12565
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([62, 57, 57, 64, 43, 75, 59, 41], [18, 29, 20, 20, 40, 21, 18, 41], [18, 13, 22, 14, 16, 3, 22, 17]).  splitting further ...
#
# splitting ... with seed: 12566
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([66, 61, 70, 71, 65, 85, 71, 60], [17, 23, 17, 15, 18, 10, 26, 25], [16, 15, 11, 13, 16, 3, 1, 13]).  splitting further ...
#
# splitting ... with seed: 12567
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([55, 46, 56, 49, 20, 57, 66, 47], [20, 28, 28, 29, 36, 25, 25, 32], [23, 25, 15, 20, 43, 17, 8, 20]).  splitting further ...
#
# splitting ... with seed: 12568
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([61, 54, 69, 62, 77, 75, 63, 68], [22, 26, 18, 21, 11, 10, 32, 19], [15, 18, 12, 15, 11, 14, 4, 11]).  splitting further ...
#
# splitting ... with seed: 12569
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([61, 58, 61, 61, 70, 82, 80, 70], [19, 23, 24, 22, 12, 14, 16, 16], [19, 18, 14, 16, 17, 3, 2, 13]).  splitting further ...
#
# splitting ... with seed: 12570
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([62, 50, 65, 59, 62, 78, 69, 58], [18, 26, 17, 20, 10, 14, 14, 19], [19, 22, 17, 19, 27, 7, 16, 21]).  splitting further ...
#
# splitting ... with seed: 12571
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([55, 57, 62, 52, 67, 71, 70, 64], [24, 25, 24, 29, 13, 17, 11, 17], [20, 17, 13, 17, 18, 10, 18, 18]).  splitting further ...
#
# splitting ... with seed: 12572
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([62, 57, 60, 59, 61, 42, 53, 54], [18, 26, 19, 22, 28, 14, 23, 24], [19, 15, 20, 18, 10, 42, 22, 20]).  splitting further ...
#
# splitting ... with seed: 12573
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([59, 63, 55, 57, 50, 57, 73, 58], [24, 23, 24, 20, 7, 21, 15, 23], [15, 13, 19, 22, 42, 21, 11, 17]).  splitting further ...
#
# splitting ... with seed: 12574
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([61, 69, 64, 63, 72, 53, 73, 58], [18, 15, 14, 17, 13, 21, 4, 16], [19, 15, 21, 18, 13, 25, 22, 24]).  splitting further ...
#
# splitting ... with seed: 12575
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([56, 63, 52, 55, 37, 53, 54, 63], [23, 23, 21, 27, 26, 17, 12, 13], [19, 13, 26, 17, 36, 28, 32, 23]).  splitting further ...
#
# splitting ... with seed: 12576
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([66, 67, 76, 78, 87, 46, 70, 72], [16, 17, 13, 11, 8, 21, 16, 17], [16, 14, 9, 9, 3, 32, 12, 10]).  splitting further ...
#
# splitting ... with seed: 12577
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([62, 65, 63, 62, 61, 78, 61, 55], [16, 18, 20, 17, 18, 14, 19, 17], [20, 15, 15, 19, 20, 7, 18, 27]).  splitting further ...
#
# splitting ... with seed: 12578
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([58, 63, 53, 66, 42, 75, 71, 71], [20, 19, 18, 14, 48, 17, 21, 19], [20, 17, 28, 19, 8, 7, 7, 8]).  splitting further ...
#
# splitting ... with seed: 12579
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([58, 59, 49, 59, 48, 71, 70, 58], [19, 25, 24, 15, 37, 10, 19, 22], [22, 15, 25, 25, 13, 17, 9, 19]).  splitting further ...
#
# splitting ... with seed: 12580
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([59, 62, 61, 49, 73, 32, 38, 48], [22, 24, 21, 25, 17, 32, 35, 27], [18, 13, 17, 24, 8, 35, 26, 23]).  splitting further ...
#
# splitting ... with seed: 12581
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([64, 67, 66, 72, 58, 17, 32, 56], [19, 13, 16, 14, 35, 42, 26, 26], [16, 19, 17, 12, 6, 39, 40, 17]).  splitting further ...
#
# splitting ... with seed: 12582
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([61, 60, 69, 65, 45, 42, 42, 54], [15, 15, 12, 16, 2, 25, 26, 16], [23, 24, 18, 18, 52, 32, 30, 29]).  splitting further ...
#
# splitting ... with seed: 12583
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([61, 54, 66, 55, 75, 50, 64, 53], [15, 30, 20, 18, 10, 3, 14, 21], [22, 15, 12, 25, 15, 46, 21, 24]).  splitting further ...
#
# splitting ... with seed: 12584
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([58, 63, 64, 52, 37, 57, 60, 66], [18, 20, 22, 33, 40, 32, 22, 19], [22, 16, 13, 14, 22, 10, 16, 13]).  splitting further ...
#
# splitting ... with seed: 12585
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([64, 63, 67, 63, 52, 53, 49, 58], [18, 12, 17, 18, 15, 35, 21, 14], [16, 23, 14, 18, 32, 10, 29, 26]).  splitting further ...
#
# splitting ... with seed: 12586
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([58, 50, 50, 59, 47, 39, 67, 47], [18, 19, 15, 13, 30, 35, 9, 29], [22, 30, 34, 26, 22, 25, 22, 23]).  splitting further ...
#
# splitting ... with seed: 12587
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([57, 52, 58, 43, 73, 67, 59, 47], [20, 26, 21, 36, 21, 17, 14, 18], [21, 21, 20, 20, 5, 14, 26, 33]).  splitting further ...
#
# splitting ... with seed: 12588
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([59, 68, 53, 56, 37, 39, 60, 58], [22, 20, 25, 21, 25, 28, 18, 32], [18, 10, 21, 22, 37, 32, 21, 9]).  splitting further ...
#
# splitting ... with seed: 12589
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([57, 52, 60, 66, 68, 64, 38, 53], [18, 27, 21, 14, 5, 14, 39, 17], [23, 20, 17, 18, 26, 21, 22, 28]).  splitting further ...
#
# splitting ... with seed: 12590
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([66, 62, 60, 63, 75, 67, 53, 57], [15, 18, 16, 7, 15, 17, 28, 17], [18, 19, 22, 29, 10, 14, 18, 25]).  splitting further ...
#
# splitting ... with seed: 12591
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([57, 56, 57, 59, 40, 53, 60, 52], [19, 10, 15, 5, 30, 3, 22, 24], [22, 32, 27, 34, 30, 42, 16, 23]).  splitting further ...
#
# splitting ... with seed: 12592
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([64, 64, 72, 70, 55, 28, 64, 67], [19, 14, 13, 8, 16, 25, 30, 11], [16, 20, 14, 21, 28, 46, 4, 21]).  splitting further ...
#
# splitting ... with seed: 12593
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([64, 52, 66, 57, 67, 39, 49, 69], [16, 17, 17, 19, 12, 46, 11, 17], [19, 30, 15, 22, 20, 14, 39, 13]).  splitting further ...
#
# splitting ... with seed: 12594
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([60, 61, 44, 62, 62, 67, 39, 72], [22, 19, 36, 18, 15, 25, 16, 17], [16, 18, 19, 18, 22, 7, 43, 10]).  splitting further ...
#
# splitting ... with seed: 12595
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([65, 63, 75, 58, 60, 82, 63, 57], [15, 22, 16, 26, 10, 7, 12, 29], [18, 14, 8, 15, 30, 10, 23, 13]).  splitting further ...
#
# splitting ... with seed: 12596
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([60, 64, 65, 75, 67, 71, 67, 68], [17, 21, 11, 13, 22, 21, 14, 11], [21, 13, 23, 11, 10, 7, 18, 19]).  splitting further ...
#
# splitting ... with seed: 12597
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([60, 58, 54, 44, 61, 42, 43, 50], [21, 23, 26, 29, 13, 21, 36, 34], [18, 18, 19, 25, 25, 35, 19, 15]).  splitting further ...
#
# splitting ... with seed: 12598
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([59, 61, 44, 64, 31, 46, 60, 62], [19, 16, 25, 11, 8, 39, 29, 14], [21, 21, 29, 24, 60, 14, 9, 23]).  splitting further ...
#
# splitting ... with seed: 12599
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([57, 53, 61, 61, 56, 57, 50, 59], [21, 20, 18, 22, 28, 25, 29, 20], [21, 25, 20, 16, 15, 17, 19, 19]).  splitting further ...
#
# splitting ... with seed: 12600
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([63, 59, 64, 62, 73, 32, 77, 64], [20, 22, 24, 25, 7, 28, 19, 18], [16, 17, 11, 11, 18, 39, 2, 17]).  splitting further ...
#
# splitting ... with seed: 12601
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([51, 52, 48, 59, 65, 64, 69, 53], [24, 30, 28, 17, 13, 21, 11, 31], [23, 17, 23, 23, 21, 14, 19, 14]).  splitting further ...
#
# splitting ... with seed: 12602
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([62, 60, 62, 52, 46, 50, 71, 65], [19, 23, 19, 30, 28, 28, 12, 16], [17, 15, 18, 17, 25, 21, 15, 17]).  splitting further ...
#
# splitting ... with seed: 12603
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([61, 58, 62, 64, 62, 42, 64, 59], [16, 21, 12, 8, 5, 28, 19, 28], [22, 19, 25, 27, 32, 28, 15, 11]).  splitting further ...
#
# splitting ... with seed: 12604
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([63, 58, 71, 53, 51, 57, 74, 53], [18, 25, 16, 14, 22, 14, 4, 21], [18, 15, 11, 31, 26, 28, 21, 24]).  splitting further ...
#
# splitting ... with seed: 12605
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([56, 58, 53, 59, 82, 42, 57, 51], [18, 21, 19, 15, 10, 17, 16, 21], [24, 20, 26, 25, 7, 39, 25, 27]).  splitting further ...
#
# splitting ... with seed: 12606
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([56, 58, 36, 60, 57, 82, 38, 60], [19, 25, 26, 19, 22, 7, 29, 22], [23, 15, 36, 19, 20, 10, 32, 17]).  splitting further ...
#
# splitting ... with seed: 12607
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([56, 52, 56, 59, 57, 78, 57, 63], [23, 22, 25, 21, 16, 17, 16, 23], [20, 25, 17, 18, 26, 3, 25, 13]).  splitting further ...
#
# splitting ... with seed: 12608
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([60, 58, 62, 61, 60, 39, 71, 64], [24, 23, 20, 17, 5, 28, 15, 23], [15, 18, 16, 20, 35, 32, 12, 12]).  splitting further ...
#
# splitting ... with seed: 12609
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([62, 71, 62, 60, 56, 46, 90, 74], [17, 9, 17, 14, 30, 3, 5, 9], [19, 18, 19, 24, 13, 50, 4, 16]).  splitting further ...
#
# splitting ... with seed: 12610
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([62, 62, 62, 51, 76, 50, 56, 62], [17, 13, 13, 24, 8, 7, 23, 11], [20, 23, 23, 23, 15, 42, 19, 26]).  splitting further ...
#
# splitting ... with seed: 12611
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([59, 63, 55, 66, 43, 75, 76, 69], [19, 21, 19, 19, 30, 14, 9, 20], [21, 14, 25, 14, 26, 10, 14, 10]).  splitting further ...
#
# splitting ... with seed: 12612
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([62, 69, 63, 59, 41, 50, 46, 70], [20, 17, 18, 24, 41, 25, 29, 17], [17, 12, 17, 15, 17, 25, 23, 11]).  splitting further ...
#
# splitting ... with seed: 12613
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([56, 64, 61, 58, 32, 60, 73, 68], [19, 16, 11, 23, 47, 14, 12, 6], [23, 19, 27, 18, 20, 25, 14, 24]).  splitting further ...
#
# splitting ... with seed: 12614
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([55, 60, 61, 44, 51, 64, 59, 57], [25, 21, 21, 30, 25, 21, 28, 21], [19, 17, 17, 24, 23, 14, 12, 21]).  splitting further ...
#
# splitting ... with seed: 12615
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([60, 65, 63, 57, 58, 57, 46, 60], [17, 17, 17, 12, 31, 25, 32, 11], [22, 16, 18, 29, 10, 17, 21, 28]).  splitting further ...
#
# splitting ... with seed: 12616
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([57, 58, 42, 43, 67, 60, 45, 43], [22, 19, 35, 22, 7, 10, 26, 33], [20, 22, 22, 33, 25, 28, 28, 23]).  splitting further ...
#
# splitting ... with seed: 12617
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([56, 56, 50, 55, 33, 46, 56, 52], [23, 16, 28, 19, 25, 21, 22, 26], [20, 26, 21, 25, 41, 32, 21, 21]).  splitting further ...
#
# splitting ... with seed: 12618
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([56, 57, 50, 52, 73, 60, 66, 52], [20, 22, 22, 19, 8, 7, 25, 35], [22, 19, 26, 27, 17, 32, 8, 12]).  splitting further ...
#
# splitting ... with seed: 12619
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([61, 63, 73, 65, 52, 46, 63, 40], [17, 17, 10, 15, 27, 28, 28, 29], [20, 19, 16, 19, 20, 25, 8, 30]).  splitting further ...
#
# splitting ... with seed: 12620
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([58, 60, 51, 53, 72, 60, 78, 52], [20, 18, 20, 25, 12], [21, 20, 28, 20, 15, 39]).  splitting further ...
#
# splitting ... with seed: 12621
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([53, 59, 39, 62, 62, 53, 59, 51], [21, 13, 25, 23, 30, 25, 21, 26], [24, 27, 34, 13, 7, 21, 19, 22]).  splitting further ...
#
# splitting ... with seed: 12622
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([55, 67, 53, 63, 77, 21, 74, 67], [22, 11, 23, 21, 12, 32, 9, 13], [21, 20, 22, 14, 10, 46, 15, 18]).  splitting further ...
#
# splitting ... with seed: 12623
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([60, 64, 61, 64, 55, 64, 53, 46], [21, 26, 20, 21, 12, 25, 21, 30], [18, 9, 17, 13, 32, 10, 25, 23]).  splitting further ...
#
# splitting ... with seed: 12624
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([52, 59, 43, 55, 61, 64, 67, 62], [26, 26, 22, 21, 8, 35, 11, 14], [21, 14, 34, 22, 30]).  splitting further ...
#
# splitting ... with seed: 12625
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([56, 60, 53, 62, 68, 64, 64, 71], [19, 22, 22, 20, 3, 10, 8, 15], [23, 16, 23, 17, 27, 25, 26, 12]).  splitting further ...
#
# splitting ... with seed: 12626
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([63, 57, 64, 60, 77, 57, 64, 68], [20, 19, 14, 21, 13, 10, 18, 19], [16, 23, 20, 17, 8, 32, 16, 11]).  splitting further ...
#
# splitting ... with seed: 12627
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([63, 56, 65, 63, 62, 46, 70, 79], [18, 19, 26, 19, 35, 21, 22, 14], [17, 23, 8, 17, 2, 32, 7, 5]).  splitting further ...
#
# splitting ... with seed: 12628
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([57, 55, 59, 53, 43, 64, 64, 49], [21, 27, 20, 29, 12, 32, 19, 30], [21, 16, 20, 16, 43, 3, 15, 19]).  splitting further ...
#
# splitting ... with seed: 12629
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([65, 61, 55, 65, 58, 46, 49, 63], [18, 17, 20, 17, 11, 10, 22, 11], [16, 20, 23, 17, 30, 42, 28, 24]).  splitting further ...
#
# splitting ... with seed: 12630
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([62, 53, 68, 72, 55, 75, 54, 67], [19, 20, 13, 16, 7, 7, 26, 18], [17, 26, 18, 11, 37, 17, 18, 13]).  splitting further ...
#
# splitting ... with seed: 12631
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([61, 63, 62, 59, 43, 64, 74, 73], [17, 21, 14, 18, 20, 10, 16, 11], [21, 15, 23, 21, 36, 25, 8, 15]).  splitting further ...
#
# splitting ... with seed: 12632
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([55, 62, 52, 52, 78, 39, 63, 65], [19, 16, 22, 25, 12, 25, 11, 15], [24, 20, 25, 21, 8, 35, 25, 18]).  splitting further ...
#
# splitting ... with seed: 12633
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([60, 52, 58, 70, 58, 82, 73, 65], [21, 23, 18, 14, 18, 3, 12, 22], [18, 23, 22, 14, 22, 14, 14, 11]).  splitting further ...
#
# splitting ... with seed: 12634
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([60, 55, 62, 61, 38, 78, 64, 62], [19, 21, 16, 16, 31, 10, 21, 22], [20, 23, 21, 22, 30, 10, 14, 15]).  splitting further ...
#
# splitting ... with seed: 12635
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([59, 65, 54, 56, 73, 21, 67, 51], [23, 19, 24, 19, 13, 50, 9, 26], [16, 15, 21, 23, 12, 28, 22, 22]).  splitting further ...
#
# splitting ... with seed: 12636
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([57, 59, 58, 61, 83, 64, 50, 60], [21, 18, 21, 16, 11, 3, 18, 26], [21, 21, 20, 22, 5, 32, 30, 12]).  splitting further ...
#
# splitting ... with seed: 12637
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([63, 54, 52, 49, 53, 75, 50, 66], [15, 16, 12, 20, 20, 7, 14, 11], [21, 29, 35, 30, 26, 17, 35, 21]).  splitting further ...
#
# splitting ... with seed: 12638
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([60, 56, 63, 65, 66, 75, 56, 66], [19, 18, 15, 10, 21, 14, 9, 14], [19, 24, 20, 23, 12, 10, 33, 18]).  splitting further ...
#
# splitting ... with seed: 12639
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([55, 60, 54, 52, 52, 42, 54, 50], [22, 18, 16, 25, 31, 46, 12, 24], [22, 21, 28, 22, 16, 10, 32, 24]).  splitting further ...
#
# splitting ... with seed: 12640
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([60, 65, 57, 49, 55, 57, 59, 55], [16, 16, 20, 29, 10, 10, 16, 21], [22, 18, 22, 21, 35, 32, 23, 23]).  splitting further ...
#
# splitting ... with seed: 12641
# Done
#
# result:  (False, True, False)
# plos_pubmed split is not yet balanced ([60, 53, 60, 58, 66, 78, 67, 57], [22, 24, 21, 25, 12, 21, 12, 31], [16, 21, 17, 16, 21]).  splitting further ...
#
# splitting ... with seed: 12642
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([61, 63, 68, 70, 58, 75, 73, 67], [18, 20, 12, 3, 17, 21, 9, 19], [19, 15, 19, 26, 23, 3, 16, 12]).  splitting further ...
#
# splitting ... with seed: 12643
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([57, 65, 54, 64, 52, 28, 59, 72], [22, 17, 28, 16, 15, 39, 19, 6], [20, 17, 17, 18, 32, 32, 21, 20]).  splitting further ...
#
# splitting ... with seed: 12644
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([64, 64, 59, 57, 80, 78, 71, 55], [18, 21, 20, 18, 11, 7, 19, 25], [17, 13, 20, 23, 8, 14, 8, 18]).  splitting further ...
#
# splitting ... with seed: 12645
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([62, 60, 74, 59, 58, 67, 53, 58], [19, 17, 13, 26, 23, 10, 26, 16], [17, 21, 11, 13, 17, 21, 19, 25]).  splitting further ...
#
# splitting ... with seed: 12646
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([63, 56, 77, 65, 56, 57, 64, 62], [13, 20, 9, 14, 33, 25, 9, 14], [22, 22, 12, 20, 10, 17, 25, 23]).  splitting further ...
#
# splitting ... with seed: 12647
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([62, 46, 69, 57, 47, 42, 70, 62], [25, 32, 19, 24, 18, 32, 15, 23], [12, 20, 11, 18, 33, 25, 14, 14]).  splitting further ...
#
# splitting ... with seed: 12648
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([56, 63, 48, 60, 62, 64, 64, 65], [25, 21, 31, 29, 31, 17, 15, 18], [17, 14, 20, 9, 6, 17, 19, 15]).  splitting further ...
#
# splitting ... with seed: 12649
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([60, 68, 56, 53, 50, 71, 61, 67], [18, 18, 23, 26, 5, 10, 18, 19], [21, 12, 19, 20, 45, 17, 19, 12]).  splitting further ...
#
# splitting ... with seed: 12650
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([56, 49, 56, 59, 51, 57, 63, 49], [23, 32, 29, 22, 32, 7, 14, 15], [19, 18, 13, 18, 16, 35, 22, 35]).  splitting further ...
#
# splitting ... with seed: 12651
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([51, 60, 49, 61, 58, 53, 53, 64], [26, 19, 28, 15, 11, 17, 32, 25], [21, 19, 22, 23, 30, 28, 14, 10]).  splitting further ...
#
# splitting ... with seed: 12652
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([57, 63, 48, 62, 56, 75, 64, 63], [23, 15, 35, 23, 15, 17, 15, 16], [18, 21, 15, 14, 28, 7, 19, 20]).  splitting further ...
#
# splitting ... with seed: 12653
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([55, 65, 47, 54, 65, 35, 54, 52], [19, 19, 19, 25, 10, 25, 23, 24], [25, 14, 32, 20, 25, 39, 21, 23]).  splitting further ...
#
# splitting ... with seed: 12654
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([61, 62, 58, 66, 60, 10, 66, 61], [17, 21, 19, 22, 31, 21, 14, 17], [20, 16, 22, 11, 8, 67, 19, 20]).  splitting further ...
#
# splitting ... with seed: 12655
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([55, 63, 53, 57, 50, 82, 47, 60], [20, 21, 24, 21, 20, 7, 29, 15], [23, 14, 21, 21, 30, 10, 22, 23]).  splitting further ...
#
# splitting ... with seed: 12656
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([57, 56, 56, 63, 68, 39, 87, 64], [24, 25, 25, 23, 15, 21, 7, 20], [18, 18, 18, 12, 16, 39, 5, 15]).  splitting further ...
#
# splitting ... with seed: 12657
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([59, 62, 52, 57, 66, 71, 39, 53], [20, 20, 24, 19, 12, 21, 15, 35], [19, 17, 23, 22, 21, 7, 45, 10]).  splitting further ...
#
# splitting ... with seed: 12658
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([65, 54, 72, 70, 48, 92, 71, 71], [15, 22, 10, 12, 11, 3, 14, 18], [18, 23, 17, 16, 40, 3, 14, 9]).  splitting further ...
#
# splitting ... with seed: 12659
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([64, 65, 70, 59, 55, 57, 74, 58], [16, 21, 12, 22, 16, 28, 12, 11], [19, 12, 16, 17, 28, 14, 12, 29]).  splitting further ...
#
# splitting ... with seed: 12660
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([58, 61, 57, 56, 70, 60, 46, 58], [19, 9, 20, 18, 17, 28, 21, 24], [22, 29, 22, 24, 12, 10, 32, 17]).  splitting further ...
#
# splitting ... with seed: 12661
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([55, 51, 56, 62, 57, 32, 61, 54], [19, 21, 22, 13, 10, 50, 19, 19], [24, 27, 20, 23, 32, 17, 18, 25]).  splitting further ...
#
# splitting ... with seed: 12662
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([59, 67, 62, 61, 72, 39, 84, 55], [20, 24, 22, 14, 11, 28, 11, 22], [20, 8, 14, 23, 16, 32, 4, 22]).  splitting further ...
#
# splitting ... with seed: 12663
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([60, 69, 57, 71, 75, 57, 70, 74], [19, 10, 22, 16, 20, 28, 11, 7], [20, 19, 20, 11, 5, 14, 18, 17]).  splitting further ...
#
# splitting ... with seed: 12664
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([64, 75, 71, 74, 41, 53, 67, 58], [17, 13, 8, 9, 26, 39, 18, 27], [18, 11, 20, 15, 32, 7, 14, 14]).  splitting further ...
#
# splitting ... with seed: 12665
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([65, 66, 60, 67, 48, 67, 76, 57], [20, 21, 30, 20, 28, 32, 8, 29], [13, 11, 8, 11, 22]).  splitting further ...
#
# splitting ... with seed: 12666
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([60, 54, 59, 59, 77, 53, 77, 67], [21, 26, 24, 30, 10, 28, 15, 17], [18, 19, 16, 10, 12, 17, 7, 14]).  splitting further ...
#
# splitting ... with seed: 12667
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([59, 64, 59, 58, 37, 60, 69, 65], [20, 16, 28, 18, 31, 14, 18, 13], [19, 19, 12, 22, 31, 25, 12, 20]).  splitting further ...
#
# splitting ... with seed: 12668
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([61, 57, 52, 55, 47, 42, 59, 58], [19, 17, 18, 15, 22, 28, 30, 20], [19, 24, 28, 29, 30, 28, 9, 21]).  splitting further ...
#
# splitting ... with seed: 12669
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([61, 60, 69, 63, 50, 92, 69, 70], [19, 19, 13, 20, 48, 3, 9, 14], [19, 20, 17, 16, 1, 3, 21, 14]).  splitting further ...
#
# splitting ... with seed: 12670
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([60, 69, 63, 66, 55, 67, 69, 55], [19, 8, 18, 11, 20, 21, 8, 14], [20, 21, 17, 22, 25, 10, 22, 29]).  splitting further ...
#
# splitting ... with seed: 12671
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([61, 56, 70, 59, 58, 60, 57, 57], [21, 21, 16, 25, 8, 21, 26, 27], [16, 21, 13, 14, 32, 17, 15, 15]).  splitting further ...
#
# splitting ... with seed: 12672
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([57, 56, 60, 61, 71, 53, 76, 73], [23, 25, 24, 22, 16, 10, 4, 12], [19, 18, 14, 16, 12, 35, 19, 13]).  splitting further ...
#
# splitting ... with seed: 12673
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([60, 61, 60, 70, 83, 85, 49, 63], [21, 20, 21, 13, 11], [18, 17, 17, 16, 5, 14, 19, 15]).  splitting further ...
#
# splitting ... with seed: 12674
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([53, 55, 62, 49, 42, 46, 73, 47], [26, 17, 22, 32, 32, 25, 8, 22], [20, 26, 15, 18, 25, 28, 18, 30]).  splitting further ...
#
# splitting ... with seed: 12675
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([66, 67, 61, 62, 57, 42, 64, 76], [16, 19, 15, 11, 28, 25, 16, 12], [16, 12, 22, 26, 13, 32, 18, 11]).  splitting further ...
#
# splitting ... with seed: 12676
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([56, 57, 55, 57, 75, 46, 76, 48], [17, 20, 16, 13, 7, 35, 8, 24], [26, 21, 27, 28, 17, 17, 15, 26]).  splitting further ...
#
# splitting ... with seed: 12677
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([57, 63, 57, 55, 46, 71, 52, 56], [24, 20, 28, 31, 27, 17, 38, 34], [18, 16, 13, 12, 26, 10, 9, 9]).  splitting further ...
#
# splitting ... with seed: 12678
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([66, 60, 62, 78, 67, 50, 80, 71], [16, 18, 17, 10, 28, 32, 14, 17], [17, 21, 20, 11, 3, 17, 5, 11]).  splitting further ...
#
# splitting ... with seed: 12679
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([57, 55, 58, 54, 58, 71, 56, 52], [19, 16, 26, 25, 30, 7, 26, 26], [22, 27, 14, 20, 11, 21, 16, 20]).  splitting further ...
#
# splitting ... with seed: 12680
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([60, 52, 60, 66, 53, 78, 60, 60], [18, 29, 18, 14, 32, 17, 15, 20], [20, 18, 21, 18, 13, 3, 23, 18]).  splitting further ...
#
# splitting ... with seed: 12681
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([62, 59, 62, 60, 72, 71, 49, 55], [18, 20, 20, 23, 20, 3, 19, 23], [18, 19, 16, 16, 7, 25, 30, 21]).  splitting further ...
#
# splitting ... with seed: 12682
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([53, 56, 51, 69, 62, 67, 70, 53], [20, 18, 22, 16, 11, 14, 16, 34], [25, 24, 25, 13, 26, 17, 12, 11]).  splitting further ...
#
# splitting ... with seed: 12683
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([59, 52, 60, 59, 53, 57, 54, 48], [20, 21, 19, 20, 10, 32, 19, 18], [19, 25, 20, 20, 36, 10, 25, 32]).  splitting further ...
#
# splitting ... with seed: 12684
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([51, 47, 46, 62, 77, 60, 71, 48], [23, 21, 33, 22, 8, 28, 7, 25], [24, 31, 19, 15, 13, 10, 21, 25]).  splitting further ...
#
# splitting ... with seed: 12685
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([57, 62, 56, 57, 50, 42, 76, 58], [21, 20, 18, 20, 42, 21, 7, 21], [20, 17, 25, 22, 7, 35, 16, 20]).  splitting further ...
#
# splitting ... with seed: 12686
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([63, 56, 64, 54, 76, 32, 57, 45], [17, 22, 19, 22, 8, 57, 22, 31], [18, 20, 16, 22, 15, 10, 19, 23]).  splitting further ...
#
# splitting ... with seed: 12687
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([57, 59, 55, 62, 43, 71, 74, 47], [14, 19, 17, 14, 8, 28, 15, 32], [27, 21, 27, 23, 47]).  splitting further ...
#
# splitting ... with seed: 12688
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([57, 57, 60, 46, 57, 53, 39, 53], [23, 25, 27, 28, 26, 39, 21, 33], [19, 17, 11, 25, 16, 7, 39, 12]).  splitting further ...
#
# splitting ... with seed: 12689
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([60, 65, 54, 54, 52, 60, 54, 57], [17, 15, 22, 25, 10, 3, 22, 27], [21, 19, 22, 19, 37, 35, 22, 15]).  splitting further ...
#
# splitting ... with seed: 12690
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([60, 65, 69, 62, 81, 71, 59, 60], [18, 20, 11, 18, 6, 7, 18, 23], [20, 14, 18, 19, 12, 21, 22, 16]).  splitting further ...
#
# splitting ... with seed: 12691
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([50, 67, 43, 52, 72, 53, 42, 60], [27, 14, 29, 29, 5, 32, 26, 23], [21, 17, 27, 18, 22, 14, 30, 16]).  splitting further ...
#
# splitting ... with seed: 12692
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([57, 60, 61, 56, 62, 42, 67, 54], [19, 19, 13, 23, 30, 25, 9, 23], [23, 19, 25, 19, 7, 32, 22, 22]).  splitting further ...
#
# splitting ... with seed: 12693
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([62, 55, 58, 53, 72, 89, 47, 57], [15, 16, 15, 22, 23, 7, 7, 10], [22, 28, 25, 23, 3, 3, 45, 32]).  splitting further ...
#
# splitting ... with seed: 12694
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([60, 58, 55, 59, 53, 39, 47, 49], [21, 17, 20, 23, 30, 39, 25, 29], [18, 23, 24, 16, 16, 21, 26, 21]).  splitting further ...
#
# splitting ... with seed: 12695
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([61, 55, 59, 60, 42, 50, 49, 66], [20, 26, 20, 22, 41, 3, 35, 11], [18, 18, 20, 16, 16, 46, 15, 21]).  splitting further ...
#
# splitting ... with seed: 12696
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([57, 52, 56, 51, 70, 82, 54, 55], [19, 27, 19, 12, 15, 10, 14, 20], [23, 19, 24, 35, 15, 7, 30, 23]).  splitting further ...
#
# splitting ... with seed: 12697
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([57, 62, 53, 62, 80, 96, 60, 56], [18, 17, 15, 19, 13, 3, 28, 25], [24, 19, 30, 17, 6]).  splitting further ...
#
# splitting ... with seed: 12698
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([61, 59, 66, 59, 48, 42, 54, 56], [22, 24, 22, 21, 22, 39, 25, 27], [16, 15, 11, 19, 28, 17, 19, 16]).  splitting further ...
#
# splitting ... with seed: 12699
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([57, 60, 67, 61, 55, 67, 70, 64], [22, 15, 16, 23, 11, 25, 19, 23], [19, 23, 15, 15, 33, 7, 9, 11]).  splitting further ...
#
# splitting ... with seed: 12700
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([56, 62, 62, 69, 70, 46, 67, 70], [23, 17, 23, 18, 5, 35, 12, 17], [20, 19, 14, 12, 25, 17, 19, 12]).  splitting further ...
#
# splitting ... with seed: 12701
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([59, 63, 62, 58, 56, 71, 80, 47], [23, 19, 19, 16, 33, 25, 4, 22], [17, 17, 17, 25, 10, 3, 15, 29]).  splitting further ...
#
# splitting ... with seed: 12702
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([56, 54, 52, 53, 60, 28, 57, 52], [20, 20, 18, 22, 27, 32, 22, 17], [23, 25, 28, 24, 12, 39, 19, 29]).  splitting further ...
#
# splitting ... with seed: 12703
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([58, 49, 53, 58, 60, 53, 73, 52], [21, 28, 22, 17, 13, 28, 8, 29], [20, 22, 23, 24, 26, 17, 18, 17]).  splitting further ...
#
# splitting ... with seed: 12704
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([58, 56, 54, 49, 87, 64, 67, 59], [23, 21, 29, 31, 5, 10, 26, 27], [18, 22, 15, 19, 7, 25, 5, 12]).  splitting further ...
#
# splitting ... with seed: 12705
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([60, 56, 67, 63, 57, 64, 60, 58], [20, 21, 17, 13, 30, 25, 26, 29], [18, 22, 14, 22, 12, 10, 12, 11]).  splitting further ...
#
# splitting ... with seed: 12706
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([65, 66, 61, 66, 78, 64, 59, 69], [16, 16, 19, 18, 13, 17, 30, 19], [18, 17, 19, 15, 7, 17, 9, 11]).  splitting further ...
#
# splitting ... with seed: 12707
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([58, 53, 62, 46, 63, 42, 60, 51], [20, 28, 17, 28, 25, 28, 16, 25], [20, 17, 19, 24, 11, 28, 22, 23]).  splitting further ...
#
# splitting ... with seed: 12708
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([65, 53, 72, 64, 76, 57, 70, 65], [18, 24, 12, 24, 17, 21, 16, 23], [16, 21, 15, 11, 6, 21, 12, 11]).  splitting further ...
#
# splitting ... with seed: 12709
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([59, 58, 66, 66, 52, 50, 28, 55], [19, 21, 12, 15, 17, 17, 43, 20], [21, 19, 20, 17, 30, 32, 28, 23]).  splitting further ...
#
# splitting ... with seed: 12710
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([53, 55, 51, 59, 35, 32, 50, 56], [21, 25, 28, 19, 22, 17, 25, 24], [24, 18, 20, 21, 42, 50, 23, 18]).  splitting further ...
#
# splitting ... with seed: 12711
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([56, 55, 63, 54, 80, 28, 66, 52], [22, 24, 18, 25, 12, 21, 18, 23], [21, 19, 18, 20, 7, 50, 15, 23]).  splitting further ...
#
# splitting ... with seed: 12712
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([64, 59, 66, 50, 27, 53, 47, 75], [15, 19, 12, 20, 16, 14, 33, 10], [20, 20, 20, 29, 56, 32, 18, 14]).  splitting further ...
#
# splitting ... with seed: 12713
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([58, 50, 46, 58, 53, 67, 59, 58], [21, 34, 24, 19, 6, 3, 4, 25], [20, 15, 29, 22, 40, 28, 36, 15]).  splitting further ...
#
# splitting ... with seed: 12714
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([61, 60, 64, 61, 33, 71, 52, 66], [20, 15, 28, 16, 27, 21, 21, 26], [18, 24, 7, 22, 38, 7, 26, 6]).  splitting further ...
#
# splitting ... with seed: 12715
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([66, 69, 63, 64, 81, 89, 74, 64], [16, 13, 17, 12, 6, 7, 15, 15], [16, 17, 19, 23, 12, 3, 9, 20]).  splitting further ...
#
# splitting ... with seed: 12716
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([59, 62, 58, 60, 78, 67, 71, 66], [16, 16, 15, 15, 15, 17, 4, 14], [24, 20, 25, 24, 6, 14, 23, 18]).  splitting further ...
#
# splitting ... with seed: 12717
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([63, 51, 75, 60, 65, 78, 30, 54], [19, 26, 12, 20, 16, 17, 25, 33], [17, 22, 12, 19, 18, 3, 43, 11]).  splitting further ...
#
# splitting ... with seed: 12718
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([65, 60, 73, 62, 91, 78, 56, 58], [17, 17, 12, 11, 2, 7, 26, 18], [17, 21, 14, 25, 6, 14, 16, 22]).  splitting further ...
#
# splitting ... with seed: 12719
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([56, 56, 54, 60, 58, 75, 67, 60], [22, 21, 32, 24, 31, 10, 14, 22], [21, 22, 13, 14, 10, 14, 18, 17]).  splitting further ...
#
# splitting ... with seed: 12720
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([52, 63, 57, 49, 52, 21, 64, 55], [19, 13, 19, 18, 10, 46, 23, 29], [27, 23, 22, 31, 37, 32, 11, 15]).  splitting further ...
#
# splitting ... with seed: 12721
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([67, 65, 67, 63, 42, 50, 43, 58], [15, 14, 16, 16, 30, 32, 33, 18], [16, 20, 16, 19, 27, 17, 22, 23]).  splitting further ...
#
# splitting ... with seed: 12722
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([61, 66, 61, 66, 70, 64, 47, 54], [17, 17, 19, 19, 18, 10, 33, 19], [20, 16, 18, 14, 11, 25, 18, 25]).  splitting further ...
#
# splitting ... with seed: 12723
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([60, 63, 53, 64, 41, 71, 71, 58], [22, 23, 24, 24, 6, 17, 5, 28], [16, 13, 21, 11, 52, 10, 22, 12]).  splitting further ...
#
# splitting ... with seed: 12724
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([59, 55, 66, 60, 62, 42, 60, 59], [17, 15, 10, 14, 18, 14, 32, 12], [23, 28, 22, 24, 18, 42, 7, 27]).  splitting further ...
#
# splitting ... with seed: 12725
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([63, 67, 62, 54, 48, 75, 54, 66], [16, 17, 14, 14, 26, 25, 22, 12], [19, 14, 22, 31, 25]).  splitting further ...
#
# splitting ... with seed: 12726
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([62, 58, 69, 66, 47, 42, 46, 68], [21, 22, 11, 22, 6, 42, 18, 13], [16, 19, 19, 11, 46, 14, 35, 17]).  splitting further ...
#
# splitting ... with seed: 12727
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([61, 65, 64, 51, 57, 64, 74, 63], [20, 18, 14, 20, 10, 7, 5, 18], [18, 16, 20, 28, 32, 28, 19, 17]).  splitting further ...
#
# splitting ... with seed: 12728
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([64, 52, 68, 73, 55, 32, 49, 51], [19, 27, 15, 17, 35, 35, 22, 29], [16, 19, 15, 8, 10, 32, 28, 19]).  splitting further ...
#
# splitting ... with seed: 12729
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([59, 58, 59, 56, 57, 53, 52, 50], [19, 24, 21, 18, 33, 28, 21, 30], [20, 17, 18, 24, 8, 17, 26, 18]).  splitting further ...
#
# splitting ... with seed: 12730
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([61, 67, 62, 55, 61, 39, 45, 59], [16, 19, 14, 23, 11, 14, 16, 23], [21, 13, 23, 21, 27, 46, 38, 16]).  splitting further ...
#
# splitting ... with seed: 12731
# Done
#
# result:  (False, False, False)
# plos_pubmed split is not yet balanced ([56, 56, 60, 61, 27, 46, 60, 64], [19, 24, 13, 19, 35, 21, 26, 14], [23, 18, 26, 18, 37, 32, 12, 20]).  splitting further ...
#
# splitting ... with seed: 12732

# %%
in_path_comb = '/home/beck/Desktop/Otimal_split/plos_pubmed_combined_bio/'
out_path_comb = '/home/beck/Desktop/Otimal_split/plos_pubmed_combined/'

#split_data(in_path_comb, out_path_comb, 204)


comb_path_whole = '/home/beck/Desktop/Otimal_split/plos_pubmed_combined_bio/'
comb_path_train = "/home/beck/Desktop/Otimal_split/plos_pubmed_combined/plos_pubmed_combined_bio_train/" 
comb_path_test = "/home/beck/Desktop/Otimal_split/plos_pubmed_combined/plos_pubmed_combined_bio_test/" 
comb_path_dev = "/home/beck/Desktop/Otimal_split/plos_pubmed_combined/plos_pubmed_combined_bio_devel/"
    
    
#calculate the distribution of class_labels for cmbined set
comb_whole_dict, comb_train_dict, comb_test_dict, comb_dev_dict = train_test_dev(comb_path_whole, 
                                                                                 comb_path_train, 
                                                                                 comb_path_test, 
                                                                                 comb_path_dev)


# calculate the proportion for each class label (8 - purposes)
comb_train_props, comb_dev_props, comb_test_props = __proportion_calculator(comb_whole_dict, 
                                                                            comb_train_dict, 
                                                                            comb_test_dict, 
                                                                            comb_dev_dict)

comb_train_result_ = _within_range_pubmed(comb_train_props)
comb_test_result_  = _within_range_dev_test(comb_test_props)
comb_dev_result_   = _within_range_dev_test(comb_dev_props)


print(f'plos+pubmed train {comb_train_props, _within_range(comb_train_props)[1]}')
print(f'plos+pubmed test  {comb_test_props, _within_range_dev_test(comb_test_props)[1]}')
print(f'plos+pubmed dev   {comb_dev_props, _within_range_dev_test(comb_dev_props)[1]}')
print()

print(f"plos+pubmed train within +/- 60% ? {_within_range(comb_train_props)[0]}")
print(f"plos+pubmed test  within +/- 15% ? {_within_range_dev_test(comb_test_props)[0]}")
print(f"plos+pubmed dev   within +/- 15% ? {_within_range_dev_test(comb_dev_props)[0]}")
print()

# train percentage 60%
    
for (k,v), (k2,v2) in zip(comb_whole_dict.items(),  comb_train_dict.items()):
    if k2 == k:
        print(f"{k2 :{18}}  {v2}/{v} train {v2/v*100: .2f}% ")

# test percentage 20% 
print()

for (k,v), (k2,v2) in zip(comb_whole_dict.items(),  comb_test_dict.items()):
    if k2 == k:
        print(f"{k2 :{18}}  {v2}/{v} test {v2/v*100: .2f}% ")
        
# dev percentage 20% 
print()

for (k,v), (k2,v2) in zip(comb_whole_dict.items(),  comb_dev_dict.items()):
    if k2 == k:
        print(f"{k2 :{18}}  {v2}/{v} dev {v2/v*100: .2f}% ")
